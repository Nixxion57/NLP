# %%
import spacy
import chardet
from spacy.matcher import Matcher

# %% [markdown]
# # Part A

# %%
nlp = spacy.load('en_core_web_md')

# %% [markdown]
# # Read the text with the correct encoding because there were some errors with some of the characters in ai_forecast1.txt and ai_forecast2.txt.

# %%
def detect_encoding(file_path):
    with open(file_path, 'rb') as f:
        result = chardet.detect(f.read())
    return result['encoding']


# Detect encoding for each file
encoding_moby_dick = detect_encoding("Texts/mobyDick.txt")
encoding_ai_forecast1 = detect_encoding("Texts/ai_forecast1.txt")
encoding_ai_forecast2 = detect_encoding("Texts/ai_forecast2.txt")

# Read files with detected encoding
moby_dick_text = open("Texts/mobyDick.txt", encoding=encoding_moby_dick).read()
ai_forecast1_text = open("Texts/ai_forecast1.txt", encoding=encoding_ai_forecast1).read()
ai_forecast2_text = open("Texts/ai_forecast2.txt", encoding=encoding_ai_forecast2).read()

# %%
# Create SpaCy documents
moby_dick_doc = nlp(moby_dick_text)
ai_forecast1_doc = nlp(ai_forecast1_text)
ai_forecast2_doc = nlp(ai_forecast2_text)

# %%
def process_doc(doc):
    print("Tokens and POS:")
    for token in doc:
        print(f"{token.text}: {token.pos_}")

    print("\nSentences:")
    for i, sent in enumerate(doc.sents):
        print(f"Sentence {i + 1}: {sent.text}")

    print("\nNamed Entities:")
    for ent in doc.ents:
        print(f"{ent.text}: {ent.label_}")

    print("\nExplain POS and grammar:")
    for token in doc[:10]:
        print("\nToken:", token.text)
        print("POS:", token.pos_)
        print("Dependency:", token.dep_)
        print("Explanation:", spacy.explain(token.pos_))


def pattern_matching_spacy_docs(docs, patterns):
    matcher = Matcher(nlp.vocab)

    # Add patterns to the matcher with their string representation as IDs
    for pattern in patterns:
        pattern_id = str(pattern)
        matcher.add(pattern_id, [pattern])

    # Initialize a dictionary to store matches
    matches_by_pattern = {}

    # Process each SpaCy document
    for doc_number, doc in enumerate(docs, start=1):
        # Find matches in the document
        matches = matcher(doc)

        # Organize matches by pattern
        for match_id, start, end in matches:
            rule_id = nlp.vocab.strings[match_id]
            span = doc[start:end]

            # Find the sentence containing the match
            sentence = next(sent.text for sent in doc.sents if span.start >= sent.start and span.end <= sent.end)

            match_info = (span.text, doc_number, sentence)
            matches_by_pattern.setdefault(rule_id, []).append(match_info)

    # Display matches for each pattern with document numbers and sentences
    for pattern_id, matched_texts in matches_by_pattern.items():
        print(f"\nMatches for pattern {pattern_id}:")
        for text, doc_number, sentence in matched_texts:
            print(f"- '{text}' found in document {doc_number} in sentence: '{sentence}'\n")

# %%
process_doc(moby_dick_doc)
# Out:
# Tokens and POS:
# It: PRON
# will: AUX
# be: AUX
# seen: VERB
# that: SCONJ
# this: DET
# mere: ADJ
# painstaking: NOUN
# burrower: NOUN
# and: CCONJ
# grub: NOUN
# -: PUNCT
# worm: NOUN
# of: ADP
#
#   : SPACE
# a: DET
# poor: ADJ
# devil: NOUN
# of: ADP
# a: DET
# Sub: PROPN
# -: PUNCT
# Sub: PROPN
# appears: VERB
# to: PART
# have: AUX
# gone: VERB
# through: ADP
# the: DET
# long: ADJ
#
#   : SPACE
# Vaticans: PROPN
# and: CCONJ
# street: NOUN
# -: PUNCT
# stalls: NOUN
# of: ADP
# the: DET
# earth: NOUN
# ,: PUNCT
# picking: VERB
# up: ADP
# whatever: DET
# random: ADJ
#
#   : SPACE
# allusions: NOUN
# to: ADP
# whales: NOUN
# he: PRON
# could: AUX
# anyways: ADV
# find: VERB
# in: ADP
# any: DET
# book: NOUN
# whatsoever: ADV
# ,: PUNCT
#
#   : SPACE
# sacred: ADJ
# or: CCONJ
# profane: ADJ
# .: PUNCT
# Therefore: ADV
# you: PRON
# must: AUX
# not: PART
# ,: PUNCT
# in: ADP
# every: DET
# case: NOUN
# at: ADP
# least: ADJ
# ,: PUNCT
#
#   : SPACE
# take: VERB
# the: DET
# higgledy: ADJ
# -: PUNCT
# piggledy: ADJ
# whale: NOUN
# statements: NOUN
# ,: PUNCT
# however: ADV
# authentic: ADJ
# ,: PUNCT
# in: ADP
#
#   : SPACE
# these: DET
# extracts: NOUN
# ,: PUNCT
# for: ADP
# veritable: ADJ
# gospel: NOUN
# cetology: NOUN
# .: PUNCT
# Far: ADV
# from: ADP
# it: PRON
# .: PUNCT
# As: SCONJ
#
#   : SPACE
# touching: VERB
# the: DET
# ancient: ADJ
# authors: NOUN
# generally: ADV
# ,: PUNCT
# as: ADV
# well: ADV
# as: ADP
# the: DET
# poets: NOUN
# here: ADV
#
#   : SPACE
# appearing: VERB
# ,: PUNCT
# these: DET
# extracts: NOUN
# are: AUX
# solely: ADV
# valuable: ADJ
# or: CCONJ
# entertaining: ADJ
# ,: PUNCT
# as: ADP
#
#   : SPACE
# affording: VERB
# a: DET
# glancing: VERB
# bird: NOUN
# ’s: PART
# eye: NOUN
# view: NOUN
# of: ADP
# what: PRON
# has: AUX
# been: AUX
# promiscuously: ADV
#
#   : SPACE
# said: VERB
# ,: PUNCT
# thought: VERB
# ,: PUNCT
# fancied: VERB
# ,: PUNCT
# and: CCONJ
# sung: VERB
# of: ADP
# Leviathan: PROPN
# ,: PUNCT
# by: ADP
# many: ADJ
# nations: NOUN
# and: CCONJ
#
#   : SPACE
# generations: NOUN
# ,: PUNCT
# including: VERB
# our: PRON
# own: ADJ
# .: PUNCT
#
#
#   : SPACE
# So: ADV
# fare: VERB
# thee: PRON
# well: ADV
# ,: PUNCT
# poor: ADJ
# devil: NOUN
# of: ADP
# a: DET
# Sub: PROPN
# -: NOUN
# Sub: NOUN
# ,: PUNCT
# whose: DET
# commentator: NOUN
# I: PRON
# am: AUX
# .: PUNCT
#
#   : SPACE
# Thou: PROPN
# belongest: ADJ
# to: ADP
# that: ADV
# hopeless: ADJ
# ,: PUNCT
# sallow: VERB
# tribe: NOUN
# which: PRON
# no: DET
# wine: NOUN
# of: ADP
# this: DET
#
#   : SPACE
# world: NOUN
# will: AUX
# ever: ADV
# warm: VERB
# ;: PUNCT
# and: CCONJ
# for: ADP
# whom: PRON
# even: ADV
# Pale: PROPN
# Sherry: PROPN
# would: AUX
# be: AUX
# too: ADV
#
#   : SPACE
# rosy: ADV
# -: PUNCT
# strong: ADJ
# ;: PUNCT
# but: CCONJ
# with: ADP
# whom: PRON
# one: NOUN
# sometimes: ADV
# loves: VERB
# to: PART
# sit: VERB
# ,: PUNCT
# and: CCONJ
# feel: VERB
#
#   : SPACE
# poor: ADJ
# -: PUNCT
# devilish: NOUN
# ,: PUNCT
# too: ADV
# ;: PUNCT
# and: CCONJ
# grow: VERB
# convivial: ADJ
# upon: SCONJ
# tears: NOUN
# ;: PUNCT
# and: CCONJ
# say: VERB
# to: ADP
# them: PRON
#
#   : SPACE
# bluntly: ADV
# ,: PUNCT
# with: ADP
# full: ADJ
# eyes: NOUN
# and: CCONJ
# empty: ADJ
# glasses: NOUN
# ,: PUNCT
# and: CCONJ
# in: ADP
# not: PART
# altogether: ADV
#
#   : SPACE
# unpleasant: ADJ
# sadness: NOUN
# —: PUNCT
# Give: VERB
# it: PRON
# up: ADP
# ,: PUNCT
# Sub: PROPN
# -: NOUN
# Subs: PROPN
# !: PUNCT
# For: ADP
# by: ADP
# how: SCONJ
# much: ADJ
# the: PRON
# more: ADJ
#
#   : SPACE
# pains: NOUN
# ye: INTJ
# take: VERB
# to: PART
# please: VERB
# the: DET
# world: NOUN
# ,: PUNCT
# by: ADP
# so: ADV
# much: ADV
# the: PRON
# more: ADJ
# shall: AUX
# ye: VERB
# for: ADP
#
#   : SPACE
# ever: ADV
# go: VERB
# thankless: ADV
# !: PUNCT
# Would: AUX
# that: SCONJ
# I: PRON
# could: AUX
# clear: VERB
# out: ADP
# Hampton: PROPN
# Court: PROPN
# and: CCONJ
# the: DET
#
#   : SPACE
# Tuileries: PROPN
# for: ADP
# ye: NOUN
# !: PUNCT
# But: CCONJ
# gulp: VERB
# down: ADP
# your: PRON
# tears: NOUN
# and: CCONJ
# hie: VERB
# aloft: ADV
# to: ADP
# the: DET
#
#   : SPACE
# royal: NOUN
# -: PUNCT
# mast: NOUN
# with: ADP
# your: PRON
# hearts: NOUN
# ;: PUNCT
# for: ADP
# your: PRON
# friends: NOUN
# who: PRON
# have: AUX
# gone: VERB
# before: ADV
#
#   : SPACE
# are: AUX
# clearing: VERB
# out: ADP
# the: DET
# seven: NUM
# -: PUNCT
# storied: ADJ
# heavens: NOUN
# ,: PUNCT
# and: CCONJ
# making: VERB
# refugees: NOUN
# of: ADP
#
#   : SPACE
# long: ADV
# -: PUNCT
# pampered: VERB
# Gabriel: PROPN
# ,: PUNCT
# Michael: PROPN
# ,: PUNCT
# and: CCONJ
# Raphael: PROPN
# ,: PUNCT
# against: ADP
# your: PRON
# coming: NOUN
# .: PUNCT
#
#   : SPACE
# Here: ADV
# ye: PRON
# strike: NOUN
# but: CCONJ
# splintered: ADJ
# hearts: NOUN
# together: ADV
# —: PUNCT
# there: ADV
# ,: PUNCT
# ye: PRON
# shall: AUX
# strike: VERB
#
#   : SPACE
# unsplinterable: ADJ
# glasses: NOUN
# !: PUNCT
#
# Sentences:
# Sentence 1: It will be seen that this mere painstaking burrower and grub-worm of
#   a poor devil of a Sub-Sub appears to have gone through the long
#   Vaticans and street-stalls of the earth, picking up whatever random
#   allusions to whales he could anyways find in any book whatsoever,
#   sacred or profane.
# Sentence 2: Therefore you must not, in every case at least,
#   take the higgledy-piggledy whale statements, however authentic, in
#   these extracts, for veritable gospel cetology.
# Sentence 3: Far from it.
# Sentence 4: As
#   touching the ancient authors generally, as well as the poets here
#   appearing, these extracts are solely valuable or entertaining, as
#   affording a glancing bird’s eye view of what has been promiscuously
#   said, thought, fancied, and sung of Leviathan, by many nations and
#   generations, including our own.
#
#
# Sentence 5: So fare thee well, poor devil of a Sub-Sub, whose commentator I am.
#
# Sentence 6: Thou belongest to that hopeless, sallow tribe which no wine of this
#   world will ever warm; and for whom even Pale Sherry would be too
#   rosy-strong; but with whom one sometimes loves to sit, and feel
#   poor-devilish, too; and grow convivial upon tears; and say to them
#   bluntly, with full eyes and empty glasses, and in not altogether
#   unpleasant sadness—Give it up, Sub-Subs!
# Sentence 7: For by how much the more
#   pains ye take to please the world, by so much the more shall ye for
#   ever go thankless!
# Sentence 8: Would that I could clear out Hampton Court and the
#   Tuileries for ye!
# Sentence 9: But gulp down your tears and hie aloft to the
#   royal-mast with your hearts; for your friends who have gone before
#   are clearing out the seven-storied heavens, and making refugees of
#   long-pampered Gabriel, Michael, and Raphael, against your coming.
#
# Sentence 10: Here ye strike but splintered hearts together—there, ye shall strike
#   unsplinterable glasses!
#
# Named Entities:
# Vaticans: PRODUCT
# Leviathan: PERSON
# Pale Sherry: PRODUCT
# one: CARDINAL
# Hampton Court: ORG
# the
#   Tuileries: ORG
# seven: CARDINAL
# Gabriel: PERSON
# Michael: PERSON
# Raphael: PERSON
#
# Explain POS and grammar:
#
# Token: It
# POS: PRON
# Dependency: nsubjpass
# Explanation: pronoun
#
# Token: will
# POS: AUX
# Dependency: aux
# Explanation: auxiliary
#
# Token: be
# POS: AUX
# Dependency: auxpass
# Explanation: auxiliary
#
# Token: seen
# POS: VERB
# Dependency: ROOT
# Explanation: verb
#
# Token: that
# POS: SCONJ
# Dependency: mark
# Explanation: subordinating conjunction
#
# Token: this
# POS: DET
# Dependency: det
# Explanation: determiner
#
# Token: mere
# POS: ADJ
# Dependency: amod
# Explanation: adjective
#
# Token: painstaking
# POS: NOUN
# Dependency: amod
# Explanation: noun
#
# Token: burrower
# POS: NOUN
# Dependency: nsubj
# Explanation: noun
#
# Token: and
# POS: CCONJ
# Dependency: cc
# Explanation: coordinating conjunction

# %%
process_doc(ai_forecast1_doc)
# Out:
# Tokens and POS:
# Pune: PROPN
# ,: PUNCT
# India: PROPN
# ,: PUNCT
# Sept.: PROPN
# 13: NUM
# ,: PUNCT
# 2022: NUM
# (: PUNCT
# GLOBE: PROPN
# NEWSWIRE: PROPN
# ): PUNCT
# --: PUNCT
# The: DET
# global: ADJ
# AI: PROPN
# market: NOUN
# size: NOUN
# is: AUX
# projected: VERB
# to: PART
# grow: VERB
# from: ADP
# USD: NOUN
# 387.45: NUM
# billion: NUM
# in: ADP
# 2022: NUM
# to: ADP
# USD: NOUN
# 1394.30: NUM
# billion: NUM
# in: ADP
# 2029: NUM
# at: ADP
# a: DET
# CAGR: NOUN
# of: ADP
# 20.1: NUM
# %: NOUN
# in: ADP
# the: DET
# forecast: NOUN
# period: NOUN
# .: PUNCT
# Growing: VERB
# investment: NOUN
# in: ADP
# AI: PROPN
# technology: NOUN
# by: ADP
# enterprises: NOUN
# of: ADP
# all: DET
# sizes: NOUN
# across: ADP
# industries: NOUN
# to: PART
# garner: VERB
# momentum: NOUN
# in: ADP
# the: DET
# next: ADJ
# several: ADJ
# years: NOUN
# .: PUNCT
# Fortune: PROPN
# Business: PROPN
# Insights: PROPN
# ™: NOUN
# published: VERB
# this: DET
# information: NOUN
# in: ADP
# its: PRON
# recent: ADJ
# report: NOUN
# ,: PUNCT
# titled: VERB
# “: PUNCT
# Artificial: PROPN
# Intelligence: PROPN
# Market: PROPN
# Forecast: PROPN
# ,: PUNCT
# 2022: NUM
# -: SYM
# 2029: NUM
# .: PUNCT
# ”: PUNCT
# As: ADP
# per: ADP
# the: DET
# report: NOUN
# ,: PUNCT
# the: DET
# global: ADJ
# market: NOUN
# size: NOUN
# was: AUX
# USD: NOUN
# 328.34: NUM
# billion: NUM
# in: ADP
# 2021: NUM
# .: PUNCT
#
# : SPACE
# The: DET
# rising: VERB
# demand: NOUN
# for: ADP
# artificial: ADJ
# intelligence: NOUN
# technology: NOUN
# across: ADP
# various: ADJ
# induce: VERB
# verticals: NOUN
# such: ADJ
# as: ADP
# a: DET
# retail: ADJ
# ,: PUNCT
# BFSI: PROPN
# ,: PUNCT
# healthcare: NOUN
# ,: PUNCT
# food: NOUN
# and: CCONJ
# beverages: NOUN
# ,: PUNCT
# automotive: ADJ
# ,: PUNCT
# and: CCONJ
# logistics: NOUN
# is: AUX
# significantly: ADV
# contributing: VERB
# towards: ADP
# the: DET
# growth: NOUN
# of: ADP
# the: DET
# global: ADJ
# market: NOUN
# .: PUNCT
#
#
# : SPACE
# Request: VERB
# a: DET
# Sample: PROPN
# Copy: PROPN
# of: ADP
# the: DET
# Research: PROPN
# Report: PROPN
# :: PUNCT
#
# : SPACE
# https://www.fortunebusinessinsights.com/enquiry/request-sample-pdf/artificial-intelligence-market-100114: PROPN
#
#
# : SPACE
# Microsoft: PROPN
# accelerates: VERB
# industry: NOUN
# cloud: ADJ
# strategy: NOUN
# for: ADP
# healthcare: NOUN
# with: ADP
# the: DET
# acquisition: NOUN
# of: ADP
# Nuance: PROPN
#
#
# : SPACE
# April: PROPN
# 12: NUM
# ,: PUNCT
# 2021: NUM
# |: SYM
# Microsoft: PROPN
# News: PROPN
# Center: PROPN
#
#
# : SPACE
# Share: NOUN
# on: ADP
# Facebook: PROPN
# (: PUNCT
# opens: VERB
# new: ADJ
# window: NOUN
# ): PUNCT
#
# : SPACE
# Share: NOUN
# on: ADP
# LinkedIn: PROPN
# (: PUNCT
# opens: VERB
# new: ADJ
# window: NOUN
# ): PUNCT
#
#
#     : SPACE
# Share: NOUN
# on: ADP
# Twitter: PROPN
# (: PUNCT
# opens: VERB
# new: ADJ
# window: NOUN
# ): PUNCT
#
#
# : SPACE
# Acquisition: PROPN
# will: AUX
# combine: VERB
# solutions: NOUN
# and: CCONJ
# expertise: NOUN
# to: PART
# deliver: VERB
# new: ADJ
# cloud: NOUN
# and: CCONJ
# AI: PROPN
# capabilities: NOUN
# across: ADP
# healthcare: NOUN
# and: CCONJ
# other: ADJ
# industries: NOUN
#
#
# : SPACE
# Microsoft: PROPN
# and: CCONJ
# Nuance: PROPN
# logos: NOUN
#
#
# : SPACE
# REDMOND: PROPN
# ,: PUNCT
# Wash.: PROPN
# ,: PUNCT
# and: CCONJ
# BURLINGTON: PROPN
# ,: PUNCT
# Mass.: PROPN
# –: PUNCT
# April: PROPN
# 12: NUM
# ,: PUNCT
# 2021: NUM
# –: PUNCT
# Microsoft: PROPN
# Corp: PROPN
# (: PUNCT
# Nasdaq: PROPN
# :: PUNCT
# MSFT: PROPN
# ): PUNCT
# and: CCONJ
# Nuance: PROPN
# Communications: PROPN
# ,: PUNCT
# Inc.: PROPN
# (: PUNCT
# Nasdaq: PROPN
# :: PUNCT
# NUAN: PROPN
# ): PUNCT
# today: NOUN
# announced: VERB
# they: PRON
# have: AUX
# entered: VERB
# into: ADP
# a: DET
# definitive: ADJ
# agreement: NOUN
# under: ADP
# which: PRON
# Microsoft: PROPN
# will: AUX
# acquire: VERB
# Nuance: PROPN
# for: ADP
# $: SYM
# 56.00: NUM
# per: ADP
# share: NOUN
# ,: PUNCT
# implying: VERB
# a: DET
# 23: NUM
# %: NOUN
# premium: NOUN
# to: ADP
# the: DET
# closing: NOUN
# price: NOUN
# of: ADP
# Nuance: PROPN
# on: ADP
# Friday: PROPN
# ,: PUNCT
# April: PROPN
# 9: NUM
# ,: PUNCT
# in: ADP
# an: DET
# all: DET
# -: PUNCT
# cash: NOUN
# transaction: NOUN
# valued: VERB
# at: ADP
# $: SYM
# 19.7: NUM
# billion: NUM
# ,: PUNCT
# inclusive: ADJ
# of: ADP
# Nuance: PROPN
# ’s: PART
# net: ADJ
# debt: NOUN
# .: PUNCT
# Nuance: NOUN
# is: AUX
# a: DET
# trusted: VERB
# cloud: NOUN
# and: CCONJ
# AI: PROPN
# software: NOUN
# leader: NOUN
# representing: VERB
# decades: NOUN
# of: ADP
# accumulated: VERB
# healthcare: NOUN
# and: CCONJ
# enterprise: NOUN
# AI: PROPN
# experience: NOUN
# .: PUNCT
# Mark: PROPN
# Benjamin: PROPN
# will: AUX
# remain: VERB
# CEO: NOUN
# of: ADP
# Nuance: PROPN
# ,: PUNCT
# reporting: VERB
# to: ADP
# Scott: PROPN
# Guthrie: PROPN
# ,: PUNCT
# executive: ADJ
# vice: NOUN
# president: NOUN
# of: ADP
# Cloud: PROPN
# &: CCONJ
# AI: PROPN
# at: ADP
# Microsoft: PROPN
# .: PUNCT
# The: DET
# transaction: NOUN
# is: AUX
# intended: VERB
# to: PART
# close: VERB
# this: DET
# calendar: NOUN
# year: NOUN
# .: PUNCT
#
#
# : SPACE
# Microsoft: PROPN
# has: AUX
# accelerated: VERB
# its: PRON
# efforts: NOUN
# to: PART
# provide: VERB
# industry: NOUN
# -: PUNCT
# specific: ADJ
# cloud: ADJ
# offerings: NOUN
# to: PART
# support: VERB
# customers: NOUN
# and: CCONJ
# partners: NOUN
# as: SCONJ
# they: PRON
# respond: VERB
# to: ADP
# disruption: NOUN
# and: CCONJ
# new: ADJ
# opportunities: NOUN
# .: PUNCT
# These: DET
# efforts: NOUN
# include: VERB
# the: DET
# Microsoft: PROPN
# Cloud: PROPN
# for: ADP
# Healthcare: PROPN
# ,: PUNCT
# introduced: VERB
# in: ADP
# 2020: NUM
# ,: PUNCT
# which: PRON
# aims: VERB
# to: PART
# address: VERB
# the: DET
# comprehensive: ADJ
# needs: NOUN
# of: ADP
# the: DET
# rapidly: ADV
# transforming: VERB
# and: CCONJ
# growing: VERB
# healthcare: NOUN
# industry: NOUN
# .: PUNCT
# Today: NOUN
# ’s: PART
# acquisition: NOUN
# announcement: NOUN
# represents: VERB
# the: DET
# latest: ADJ
# step: NOUN
# in: ADP
# Microsoft: PROPN
# ’s: PART
# industry: NOUN
# -: PUNCT
# specific: ADJ
# cloud: NOUN
# strategy: NOUN
# .: PUNCT
#
#
# : SPACE
# Nuance: PROPN
# is: AUX
# a: DET
# pioneer: NOUN
# and: CCONJ
# a: DET
# leading: VERB
# provider: NOUN
# of: ADP
# conversational: ADJ
# AI: PROPN
# and: CCONJ
# cloud: NOUN
# -: PUNCT
# based: VERB
# ambient: NOUN
# clinical: ADJ
# intelligence: NOUN
# for: ADP
# healthcare: NOUN
# providers: NOUN
# .: PUNCT
# Nuance: NOUN
# ’s: PART
# products: NOUN
# include: VERB
# the: DET
# Dragon: PROPN
# Ambient: PROPN
# eXperience: PROPN
# ,: PUNCT
# Dragon: PROPN
# Medical: PROPN
# One: PROPN
# and: CCONJ
# PowerScribe: PROPN
# One: NUM
# for: ADP
# radiology: NOUN
# reporting: NOUN
# ,: PUNCT
# all: DET
# leading: VERB
# clinical: ADJ
# speech: NOUN
# recognition: NOUN
# SaaS: ADJ
# offerings: NOUN
# built: VERB
# on: ADP
# Microsoft: PROPN
# Azure: PROPN
# .: PUNCT
# Nuance: NOUN
# ’s: PART
# solutions: NOUN
# work: VERB
# seamlessly: ADV
# with: ADP
# core: PROPN
# healthcare: PROPN
# systems: NOUN
# ,: PUNCT
# including: VERB
# longstanding: ADJ
# relationships: NOUN
# with: ADP
# Electronic: PROPN
# Health: PROPN
# Records: PROPN
# (: PUNCT
# EHRs: PROPN
# ): PUNCT
# ,: PUNCT
# to: PART
# alleviate: VERB
# the: DET
# burden: NOUN
# of: ADP
# clinical: ADJ
# documentation: NOUN
# and: CCONJ
# empower: VERB
# providers: NOUN
# to: PART
# deliver: VERB
# better: ADJ
# patient: ADJ
# experiences: NOUN
# .: PUNCT
# Nuance: NOUN
# solutions: NOUN
# are: AUX
# currently: ADV
# used: VERB
# by: ADP
# more: ADJ
# than: ADP
# 55: NUM
# %: NOUN
# of: ADP
# physicians: NOUN
# and: CCONJ
# 75: NUM
# %: NOUN
# of: ADP
# radiologists: NOUN
# in: ADP
# the: DET
# U.S.: PROPN
# ,: PUNCT
# and: CCONJ
# used: VERB
# in: ADP
# 77: NUM
# %: NOUN
# of: ADP
# U.S.: PROPN
# hospitals: NOUN
# .: PUNCT
# Nuance: PROPN
# ’s: PART
# Healthcare: PROPN
# Cloud: PROPN
# revenue: NOUN
# experienced: VERB
# 37: NUM
# %: NOUN
# year: NOUN
# -: PUNCT
# over: ADP
# -: PUNCT
# year: NOUN
# growth: NOUN
# in: ADP
# Nuance: PROPN
# ’s: PART
# fiscal: ADJ
# year: NOUN
# 2020: NUM
# (: PUNCT
# ended: VERB
# September: PROPN
# 2020: NUM
# ): PUNCT
# .: PUNCT
#
#
# : SPACE
# Microsoft: PROPN
# ’s: PART
# acquisition: NOUN
# of: ADP
# Nuance: PROPN
# builds: VERB
# upon: SCONJ
# the: DET
# successful: ADJ
# existing: VERB
# partnership: NOUN
# between: ADP
# the: DET
# companies: NOUN
# that: PRON
# was: AUX
# announced: VERB
# in: ADP
# 2019: NUM
# .: PUNCT
# By: ADP
# augmenting: VERB
# the: DET
# Microsoft: PROPN
# Cloud: PROPN
# for: ADP
# Healthcare: PROPN
# with: ADP
# Nuance: PROPN
# ’s: PART
# solutions: NOUN
# ,: PUNCT
# as: ADV
# well: ADV
# as: ADP
# the: DET
# benefit: NOUN
# of: ADP
# Nuance: PROPN
# ’s: PART
# expertise: NOUN
# and: CCONJ
# relationships: NOUN
# with: ADP
# EHR: NOUN
# systems: NOUN
# providers: NOUN
# ,: PUNCT
# Microsoft: PROPN
# will: AUX
# be: AUX
# better: ADV
# able: ADJ
# to: PART
# empower: VERB
# healthcare: NOUN
# providers: NOUN
# through: ADP
# the: DET
# power: NOUN
# of: ADP
# ambient: ADJ
# clinical: ADJ
# intelligence: NOUN
# and: CCONJ
# other: ADJ
# Microsoft: PROPN
# cloud: NOUN
# services: NOUN
# .: PUNCT
# The: DET
# acquisition: NOUN
# will: AUX
# double: VERB
# Microsoft: PROPN
# ’s: PART
# total: ADJ
# addressable: ADJ
# market: NOUN
# (: PUNCT
# TAM: PROPN
# ): PUNCT
# in: ADP
# the: DET
# healthcare: NOUN
# provider: NOUN
# space: NOUN
# ,: PUNCT
# bringing: VERB
# the: DET
# company: NOUN
# ’s: PART
# TAM: PROPN
# in: ADP
# healthcare: NOUN
# to: ADP
# nearly: ADV
# $: SYM
# 500: NUM
# billion: NUM
# .: PUNCT
# Nuance: NOUN
# and: CCONJ
# Microsoft: PROPN
# will: AUX
# deepen: VERB
# their: PRON
# existing: VERB
# commitments: NOUN
# to: ADP
# the: DET
# extended: ADJ
# partner: NOUN
# ecosystem: NOUN
# ,: PUNCT
# as: ADV
# well: ADV
# as: ADP
# the: DET
# highest: ADJ
# standards: NOUN
# of: ADP
# data: NOUN
# privacy: NOUN
# ,: PUNCT
# security: NOUN
# and: CCONJ
# compliance: NOUN
# .: PUNCT
#
#
# : SPACE
# “: PUNCT
# Nuance: NOUN
# provides: VERB
# the: DET
# AI: PROPN
# layer: NOUN
# at: ADP
# the: DET
# healthcare: NOUN
# point: NOUN
# of: ADP
# delivery: NOUN
# and: CCONJ
# is: AUX
# a: DET
# pioneer: NOUN
# in: ADP
# the: DET
# real: ADJ
# -: PUNCT
# world: NOUN
# application: NOUN
# of: ADP
# enterprise: NOUN
# AI: PROPN
# ,: PUNCT
# ”: PUNCT
# said: VERB
# Satya: PROPN
# Nadella: PROPN
# ,: PUNCT
# CEO: PROPN
# ,: PUNCT
# Microsoft: PROPN
# .: PUNCT
# “: PUNCT
# AI: PROPN
# is: AUX
# technology: NOUN
# ’s: PART
# most: ADV
# important: ADJ
# priority: NOUN
# ,: PUNCT
# and: CCONJ
# healthcare: NOUN
# is: AUX
# its: PRON
# most: ADV
# urgent: ADJ
# application: NOUN
# .: PUNCT
# Together: ADV
# ,: PUNCT
# with: ADP
# our: PRON
# partner: NOUN
# ecosystem: NOUN
# ,: PUNCT
# we: PRON
# will: AUX
# put: VERB
# advanced: ADJ
# AI: PROPN
# solutions: NOUN
# into: ADP
# the: DET
# hands: NOUN
# of: ADP
# professionals: NOUN
# everywhere: ADV
# to: PART
# drive: VERB
# better: ADJ
# decision: NOUN
# -: PUNCT
# making: NOUN
# and: CCONJ
# create: VERB
# more: ADV
# meaningful: ADJ
# connections: NOUN
# ,: PUNCT
# as: SCONJ
# we: PRON
# accelerate: VERB
# growth: NOUN
# of: ADP
# Microsoft: PROPN
# Cloud: PROPN
# for: ADP
# Healthcare: PROPN
# and: CCONJ
# Nuance: PROPN
# .: PUNCT
# ”: PUNCT
#
#
# : SPACE
# Beyond: ADP
# healthcare: NOUN
# ,: PUNCT
# Nuance: PROPN
# provides: VERB
# AI: PROPN
# expertise: NOUN
# and: CCONJ
# customer: NOUN
# engagement: NOUN
# solutions: NOUN
# across: ADP
# Interactive: PROPN
# Voice: PROPN
# Response: PROPN
# (: PUNCT
# IVR: PROPN
# ): PUNCT
# ,: PUNCT
# virtual: ADJ
# assistants: NOUN
# ,: PUNCT
# and: CCONJ
# digital: ADJ
# and: CCONJ
# biometric: ADJ
# solutions: NOUN
# to: ADP
# companies: NOUN
# around: ADP
# the: DET
# world: NOUN
# across: ADP
# all: DET
# industries: NOUN
# .: PUNCT
# This: DET
# expertise: NOUN
# will: AUX
# come: VERB
# together: ADV
# with: ADP
# the: DET
# breadth: NOUN
# and: CCONJ
# depth: NOUN
# of: ADP
# Microsoft: PROPN
# ’s: PART
# cloud: NOUN
# ,: PUNCT
# including: VERB
# Azure: PROPN
# ,: PUNCT
# Teams: PROPN
# ,: PUNCT
# and: CCONJ
# Dynamics: PROPN
# 365: NUM
# ,: PUNCT
# to: PART
# deliver: VERB
# next: ADJ
# -: PUNCT
# generation: NOUN
# customer: NOUN
# engagement: NOUN
# and: CCONJ
# security: NOUN
# solutions: NOUN
# .: PUNCT
#
#
# : SPACE
# “: PUNCT
# Over: ADP
# the: DET
# past: ADJ
# three: NUM
# years: NOUN
# ,: PUNCT
# Nuance: PROPN
# has: AUX
# streamlined: VERB
# its: PRON
# portfolio: NOUN
# to: PART
# focus: VERB
# on: ADP
# the: DET
# healthcare: NOUN
# and: CCONJ
# enterprise: NOUN
# AI: PROPN
# segments: NOUN
# ,: PUNCT
# where: SCONJ
# there: PRON
# has: AUX
# been: AUX
# accelerated: VERB
# demand: NOUN
# for: ADP
# advanced: ADJ
# conversational: ADJ
# AI: PROPN
# and: CCONJ
# ambient: ADJ
# solutions: NOUN
# ,: PUNCT
# ”: PUNCT
# said: VERB
# Mark: PROPN
# Benjamin: PROPN
# ,: PUNCT
# CEO: PROPN
# ,: PUNCT
# Nuance: PROPN
# .: PUNCT
# “: PUNCT
# To: PART
# seize: VERB
# this: DET
# opportunity: NOUN
# ,: PUNCT
# we: PRON
# need: VERB
# the: DET
# right: ADJ
# platform: NOUN
# to: PART
# bring: VERB
# focus: NOUN
# and: CCONJ
# global: ADJ
# scale: NOUN
# to: ADP
# our: PRON
# customers: NOUN
# and: CCONJ
# partners: NOUN
# to: PART
# enable: VERB
# more: ADV
# personal: ADJ
# ,: PUNCT
# affordable: ADJ
# and: CCONJ
# effective: ADJ
# connections: NOUN
# to: ADP
# people: NOUN
# and: CCONJ
# care: NOUN
# .: PUNCT
# The: DET
# path: NOUN
# forward: ADV
# is: AUX
# clearly: ADV
# with: ADP
# Microsoft: PROPN
# —: PUNCT
#  : SPACE
# who: PRON
# brings: VERB
# intelligent: ADJ
# cloud: NOUN
# -: PUNCT
# based: VERB
# services: NOUN
# at: ADP
# scale: NOUN
# and: CCONJ
# who: PRON
# shares: VERB
# our: PRON
# passion: NOUN
# for: ADP
# the: DET
# ways: NOUN
# technology: NOUN
# can: AUX
# make: VERB
# a: DET
# difference: NOUN
# .: PUNCT
# At: ADP
# the: DET
# same: ADJ
# time: NOUN
# ,: PUNCT
# this: DET
# combination: NOUN
# offers: VERB
# a: DET
# critical: ADJ
# opportunity: NOUN
# to: PART
# deliver: VERB
# meaningful: ADJ
# and: CCONJ
# certain: ADJ
# value: NOUN
# to: ADP
# our: PRON
# shareholders: NOUN
# who: PRON
# have: AUX
# driven: VERB
# and: CCONJ
# supported: VERB
# us: PRON
# on: ADP
# this: DET
# journey: NOUN
# .: PUNCT
# ”: PUNCT
#
#
# : SPACE
# The: DET
# transaction: NOUN
# has: AUX
# been: AUX
# unanimously: ADV
# approved: VERB
# by: ADP
# the: DET
# Boards: PROPN
# of: ADP
# Directors: PROPN
# of: ADP
# both: DET
# Nuance: PROPN
# and: CCONJ
# Microsoft: PROPN
# .: PUNCT
# The: DET
# deal: NOUN
# is: AUX
# intended: VERB
# to: PART
# close: VERB
# by: ADP
# the: DET
# end: NOUN
# of: ADP
# this: DET
# calendar: NOUN
# year: NOUN
# and: CCONJ
# is: AUX
# subject: ADJ
# to: ADP
# approval: NOUN
# by: ADP
# Nuance: PROPN
# ’s: PART
# shareholders: NOUN
# ,: PUNCT
# the: DET
# satisfaction: NOUN
# of: ADP
# certain: ADJ
# regulatory: ADJ
# approvals: NOUN
# ,: PUNCT
# and: CCONJ
# other: ADJ
# customary: ADJ
# closing: NOUN
# conditions: NOUN
# .: PUNCT
#
#
# : SPACE
# Upon: SCONJ
# closing: VERB
# ,: PUNCT
# Microsoft: PROPN
# expects: VERB
# Nuance: PROPN
# ’s: PART
# financials: NOUN
# to: PART
# be: AUX
# reported: VERB
# as: ADP
# part: NOUN
# of: ADP
# Microsoft: PROPN
# ’s: PART
# Intelligent: PROPN
# Cloud: PROPN
# segment: NOUN
# .: PUNCT
# Microsoft: PROPN
# expects: VERB
# the: DET
# acquisition: NOUN
# to: PART
# be: AUX
# minimally: ADV
# dilutive: ADJ
# (: PUNCT
# less: ADJ
# than: ADP
# 1: NUM
# percent: NOUN
# ): PUNCT
# in: ADP
# fiscal: ADJ
# year: NOUN
# 2022: NUM
# and: CCONJ
# to: PART
# be: AUX
# accretive: ADJ
# in: ADP
# fiscal: ADJ
# year: NOUN
# 2023: NUM
# to: ADP
# non: ADJ
# -: ADJ
# GAAP: ADJ
# earnings: NOUN
# per: ADP
# share: NOUN
# ,: PUNCT
# based: VERB
# on: ADP
# the: DET
# expected: VERB
# close: ADJ
# timeframe: NOUN
# .: PUNCT
# Non: NOUN
# -: NOUN
# GAAP: NOUN
# excludes: VERB
# expected: VERB
# impact: NOUN
# of: ADP
# purchase: NOUN
# accounting: NOUN
# adjustments: NOUN
# ,: PUNCT
# as: ADV
# well: ADV
# as: ADP
# integration: NOUN
# and: CCONJ
# transaction: NOUN
# -: PUNCT
# related: VERB
# expenses: NOUN
# .: PUNCT
# The: DET
# acquisition: NOUN
# will: AUX
# not: PART
# impact: VERB
# the: DET
# completion: NOUN
# of: ADP
# its: PRON
# existing: VERB
# share: NOUN
# repurchase: NOUN
# authorization: NOUN
# .: PUNCT
#
#
# : SPACE
# Nadella: PROPN
# ,: PUNCT
# Benjamin: PROPN
# ,: PUNCT
# Guthrie: PROPN
# and: CCONJ
# Microsoft: PROPN
# Chief: PROPN
# Financial: PROPN
# Officer: PROPN
# Amy: PROPN
# Hood: PROPN
# will: AUX
# host: VERB
# a: DET
# webcast: NOUN
# for: ADP
# investors: NOUN
# and: CCONJ
# media: NOUN
# on: ADP
# April: PROPN
# 12: NUM
# ,: PUNCT
# 2021: NUM
# ,: PUNCT
# at: ADP
# 8: NUM
# a.m.: NOUN
# Pacific: PROPN
# Time/11: PROPN
# a.m.: NOUN
# Eastern: PROPN
# Time: PROPN
# regarding: VERB
# this: DET
# transaction: NOUN
# .: PUNCT
# The: DET
# presentation: NOUN
# is: AUX
# available: ADJ
# via: ADP
# webcast: NOUN
# at: ADP
# https://aka.ms/MS-Investor-Call: NUM
# or: CCONJ
# to: ADP
# international: ADJ
# callers: NOUN
# at: ADP
# +1: PROPN
# (: PUNCT
# 201: NUM
# ): PUNCT
# 689: NUM
# -: SYM
# 8023: NUM
# (: PUNCT
# no: DET
# password: NOUN
# required: VERB
# ): PUNCT
# ,: PUNCT
# or: CCONJ
# to: ADP
# U.S.: PROPN
# callers: NOUN
# at: ADP
# (: PUNCT
# 877: NUM
# ): PUNCT
# 407: NUM
# -: SYM
# 0666: NUM
# (: PUNCT
# no: DET
# password: NOUN
# required: VERB
# ): PUNCT
# ,: PUNCT
# at: ADP
# that: DET
# time: NOUN
# .: PUNCT
#
#
# : SPACE
# Goldman: PROPN
# Sachs: PROPN
# &: CCONJ
# Co.: PROPN
# LLC: PROPN
# is: AUX
# acting: VERB
# as: ADP
# exclusive: ADJ
# financial: ADJ
# advisor: NOUN
# to: ADP
# Microsoft: PROPN
# ,: PUNCT
# while: SCONJ
# Simpson: PROPN
# Thacher: PROPN
# &: CCONJ
# Bartlett: PROPN
# LLP: PROPN
# is: AUX
# acting: VERB
# as: ADP
# its: PRON
# legal: ADJ
# advisor: NOUN
# .: PUNCT
# Evercore: NOUN
# is: AUX
# acting: VERB
# as: ADP
# exclusive: ADJ
# financial: ADJ
# advisor: NOUN
# to: ADP
# Nuance: PROPN
# ,: PUNCT
# while: SCONJ
# Paul: PROPN
# ,: PUNCT
# Weiss: PROPN
# ,: PUNCT
# Rifkind: PROPN
# ,: PUNCT
# Wharton: PROPN
# &: CCONJ
# Garrison: PROPN
# LLP: PROPN
# is: AUX
# acting: VERB
# as: ADP
# its: PRON
# legal: ADJ
# advisor: NOUN
# .: PUNCT
#
#
# : SPACE
# About: ADP
# Microsoft: PROPN
#
# : SPACE
# Microsoft: PROPN
# (: PUNCT
# Nasdaq: PROPN
# “: PUNCT
# MSFT: PROPN
# ”: PUNCT
# @microsoft: PROPN
# ): PUNCT
# enables: VERB
# digital: ADJ
# transformation: NOUN
# for: ADP
# the: DET
# era: NOUN
# of: ADP
# an: DET
# intelligent: ADJ
# cloud: NOUN
# and: CCONJ
# an: DET
# intelligent: ADJ
# edge: NOUN
# .: PUNCT
# Its: PRON
# mission: NOUN
# is: AUX
# to: PART
# empower: VERB
# every: DET
# person: NOUN
# and: CCONJ
# every: DET
# organization: NOUN
# on: ADP
# the: DET
# planet: NOUN
# to: PART
# achieve: VERB
# more: ADJ
# .: PUNCT
#
#
# : SPACE
# About: ADP
# Nuance: PROPN
# Communications: PROPN
# ,: PUNCT
# Inc.: PROPN
#
# : SPACE
# Nuance: PROPN
# Communications: PROPN
# (: PUNCT
# NASDAQ: PROPN
# :: PUNCT
# NUAN: PROPN
# ): PUNCT
# is: AUX
# a: DET
# technology: NOUN
# pioneer: NOUN
# with: ADP
# market: NOUN
# leadership: NOUN
# in: ADP
# conversational: ADJ
# AI: PROPN
# and: CCONJ
# ambient: ADJ
# intelligence: NOUN
# .: PUNCT
# A: DET
# full: ADJ
# -: PUNCT
# service: NOUN
# partner: NOUN
# trusted: VERB
# by: ADP
# 77: NUM
# percent: NOUN
# of: ADP
# U.S.: PROPN
# hospitals: NOUN
# and: CCONJ
# 85: NUM
# percent: NOUN
# of: ADP
# the: DET
# Fortune: PROPN
# 100: NUM
# companies: NOUN
# worldwide: ADV
# ,: PUNCT
# Nuance: PROPN
# creates: VERB
# intuitive: ADJ
# solutions: NOUN
# that: PRON
# amplify: VERB
# people: NOUN
# ’s: PART
# ability: NOUN
# to: PART
# help: VERB
# others: NOUN
# .: PUNCT
#
#
# : SPACE
# For: ADP
# more: ADJ
# information: NOUN
# ,: PUNCT
# press: VERB
# only: ADV
# :: PUNCT
#
#
# : SPACE
# Microsoft: PROPN
# Media: PROPN
# Relations: PROPN
# ,: PUNCT
# WE: PROPN
# Communications: PROPN
# ,: PUNCT
# (: PUNCT
# 425: NUM
# ): PUNCT
# 638: NUM
# -: PUNCT
# 7777: NUM
# ,: PUNCT
# rrt@we-worldwide.com: X
#
#
# : SPACE
# Note: NOUN
# to: ADP
# editors: NOUN
# :: PUNCT
# For: ADP
# more: ADJ
# information: NOUN
# ,: PUNCT
# news: NOUN
# and: CCONJ
# perspectives: NOUN
# from: ADP
# Microsoft: PROPN
# ,: PUNCT
# please: INTJ
# visit: VERB
# the: DET
# Microsoft: PROPN
# News: PROPN
# Center: PROPN
# at: ADP
# http://news.microsoft.com: NUM
# .: PUNCT
# Web: NOUN
# links: NOUN
# ,: PUNCT
# telephone: NOUN
# numbers: NOUN
# and: CCONJ
# titles: NOUN
# were: AUX
# correct: ADJ
# at: ADP
# time: NOUN
# of: ADP
# publication: NOUN
# but: CCONJ
# may: AUX
# have: AUX
# changed: VERB
# .: PUNCT
# For: ADP
# additional: ADJ
# assistance: NOUN
# ,: PUNCT
# journalists: NOUN
# and: CCONJ
# analysts: NOUN
# may: AUX
# contact: VERB
# Microsoft: PROPN
# ’s: PART
# Rapid: PROPN
# Response: PROPN
# Team: PROPN
# or: CCONJ
# other: ADJ
# appropriate: ADJ
# contacts: NOUN
# listed: VERB
# at: ADP
# https://news.microsoft.com/microsoft-public-relations-contacts: NOUN
# .: PUNCT
#
#
# : SPACE
# Trademark: PROPN
# reference: NOUN
# :: PUNCT
# Nuance: NOUN
# and: CCONJ
# the: DET
# Nuance: PROPN
# logo: NOUN
# are: AUX
# registered: VERB
# trademarks: NOUN
# or: CCONJ
# trademarks: NOUN
# of: ADP
# Nuance: PROPN
# Communications: PROPN
# ,: PUNCT
# Inc.: PROPN
# or: CCONJ
# its: PRON
# affiliates: NOUN
# in: ADP
# the: DET
# United: PROPN
# States: PROPN
# and/or: CCONJ
# other: ADJ
# countries: NOUN
# .: PUNCT
# All: DET
# other: ADJ
# trademarks: NOUN
#
# Sentences:
# Sentence 1: Pune, India, Sept. 13, 2022 (GLOBE NEWSWIRE) --
# Sentence 2: The global AI market size is projected to grow from USD 387.45 billion in 2022 to USD 1394.30 billion in 2029 at a CAGR of 20.1% in the forecast period.
# Sentence 3: Growing investment in AI technology by enterprises of all sizes across industries to garner momentum in the next several years.
# Sentence 4: Fortune Business Insights™ published this information in its recent report, titled “Artificial Intelligence Market Forecast, 2022-2029.”
# Sentence 5: As per the report, the global market size was USD 328.34 billion in 2021.
#
# Sentence 6: The rising demand for artificial intelligence technology across various induce verticals such as a retail, BFSI, healthcare, food and beverages, automotive, and logistics is significantly contributing towards the growth of the global market.
#
#
# Sentence 7: Request a Sample Copy of the Research Report:
# https://www.fortunebusinessinsights.com/enquiry/request-sample-pdf/artificial-intelligence-market-100114
#
# Microsoft accelerates industry cloud strategy for healthcare with the acquisition of Nuance
#
# April 12, 2021 | Microsoft News Center
#
# Share on Facebook (opens new window)
#
# Sentence 8: Share on LinkedIn (opens new window)
#
#     Share on Twitter (opens new window)
#
# Acquisition will combine solutions and expertise to deliver new cloud and AI capabilities across healthcare and other industries
#
# Microsoft and Nuance logos
#
# REDMOND, Wash., and BURLINGTON, Mass. – April 12, 2021 – Microsoft Corp (Nasdaq: MSFT) and Nuance Communications, Inc. (Nasdaq: NUAN) today announced they have entered into a definitive agreement under which Microsoft will acquire Nuance for $56.00 per share, implying a 23% premium to the closing price of Nuance on Friday, April 9, in an all-cash transaction valued at $19.7 billion, inclusive of Nuance’s net debt.
# Sentence 9: Nuance is a trusted cloud and AI software leader representing decades of accumulated healthcare and enterprise AI experience.
# Sentence 10: Mark Benjamin will remain CEO of Nuance, reporting to Scott Guthrie, executive vice president of Cloud & AI at Microsoft.
# Sentence 11: The transaction is intended to close this calendar year.
#
#
# Sentence 12: Microsoft has accelerated its efforts to provide industry-specific cloud offerings to support customers and partners as they respond to disruption and new opportunities.
# Sentence 13: These efforts include the Microsoft Cloud for Healthcare, introduced in 2020, which aims to address the comprehensive needs of the rapidly transforming and growing healthcare industry.
# Sentence 14: Today’s acquisition announcement represents the latest step in Microsoft’s industry-specific cloud strategy.
#
#
# Sentence 15: Nuance is a pioneer and a leading provider of conversational AI and cloud-based ambient clinical intelligence for healthcare providers.
# Sentence 16: Nuance’s products include the Dragon Ambient eXperience, Dragon Medical One and PowerScribe One for radiology reporting, all leading clinical speech recognition SaaS offerings built on Microsoft Azure.
# Sentence 17: Nuance’s solutions work seamlessly with core healthcare systems, including longstanding relationships with Electronic Health Records (EHRs), to alleviate the burden of clinical documentation and empower providers to deliver better patient experiences.
# Sentence 18: Nuance solutions are currently used by more than 55% of physicians and 75% of radiologists in the U.S., and used in 77% of U.S. hospitals.
# Sentence 19: Nuance’s Healthcare Cloud revenue experienced 37% year-over-year growth in Nuance’s fiscal year 2020 (ended September 2020).
#
#
# Sentence 20: Microsoft’s acquisition of Nuance builds upon the successful existing partnership between the companies that was announced in 2019.
# Sentence 21: By augmenting the Microsoft Cloud for Healthcare with Nuance’s solutions, as well as the benefit of Nuance’s expertise and relationships with EHR systems providers, Microsoft will be better able to empower healthcare providers through the power of ambient clinical intelligence and other Microsoft cloud services.
# Sentence 22: The acquisition will double Microsoft’s total addressable market (TAM) in the healthcare provider space, bringing the company’s TAM in healthcare to nearly $500 billion.
# Sentence 23: Nuance and Microsoft will deepen their existing commitments to the extended partner ecosystem, as well as the highest standards of data privacy, security and compliance.
#
#
# Sentence 24: “Nuance provides the AI layer at the healthcare point of delivery and is a pioneer in the real-world application of enterprise AI,” said Satya Nadella, CEO, Microsoft.
# Sentence 25: “AI is technology’s most important priority, and healthcare is its most urgent application.
# Sentence 26: Together, with our partner ecosystem, we will put advanced AI solutions into the hands of professionals everywhere to drive better decision-making and create more meaningful connections, as we accelerate growth of Microsoft Cloud for Healthcare and Nuance.”
#
# Beyond healthcare, Nuance provides AI expertise and customer engagement solutions across Interactive Voice Response (IVR), virtual assistants, and digital and biometric solutions to companies around the world across all industries.
# Sentence 27: This expertise will come together with the breadth and depth of Microsoft’s cloud, including Azure, Teams, and Dynamics 365, to deliver next-generation customer engagement and security solutions.
#
#
# Sentence 28: “Over the past three years, Nuance has streamlined its portfolio to focus on the healthcare and enterprise AI segments, where there has been accelerated demand for advanced conversational AI and ambient solutions,” said Mark Benjamin, CEO, Nuance.
# Sentence 29: “To seize this opportunity, we need the right platform to bring focus and global scale to our customers and partners to enable more personal, affordable and effective connections to people and care.
# Sentence 30: The path forward is clearly with Microsoft —  who brings intelligent cloud-based services at scale and who shares our passion for the ways technology can make a difference.
# Sentence 31: At the same time, this combination offers a critical opportunity to deliver meaningful and certain value to our shareholders who have driven and supported us on this journey.”
#
#
# Sentence 32: The transaction has been unanimously approved by the Boards of Directors of both Nuance and Microsoft.
# Sentence 33: The deal is intended to close by the end of this calendar year and is subject to approval by Nuance’s shareholders, the satisfaction of certain regulatory approvals, and other customary closing conditions.
#
#
# Sentence 34: Upon closing, Microsoft expects Nuance’s financials to be reported as part of Microsoft’s Intelligent Cloud segment.
# Sentence 35: Microsoft expects the acquisition to be minimally dilutive (less than 1 percent) in fiscal year 2022 and to be accretive in fiscal year 2023 to non-GAAP earnings per share, based on the expected close timeframe.
# Sentence 36: Non-GAAP excludes expected impact of purchase accounting adjustments, as well as integration and transaction-related expenses.
# Sentence 37: The acquisition will not impact the completion of its existing share repurchase authorization.
#
#
# Sentence 38: Nadella, Benjamin, Guthrie and Microsoft Chief Financial Officer Amy Hood will host a webcast for investors and media on April 12, 2021, at 8 a.m.
# Sentence 39: Pacific Time/11 a.m.
# Sentence 40: Eastern Time regarding this transaction.
# Sentence 41: The presentation is available via webcast at https://aka.ms/MS-Investor-Call or to international callers at +1 (201) 689-8023 (no password required), or to U.S. callers at (877) 407-0666 (no password required), at that time.
#
#
# Sentence 42: Goldman Sachs & Co. LLC is acting as exclusive financial advisor to Microsoft, while Simpson Thacher & Bartlett LLP is acting as its legal advisor.
# Sentence 43: Evercore is acting as exclusive financial advisor to Nuance, while Paul, Weiss, Rifkind, Wharton & Garrison LLP is acting as its legal advisor.
#
#
# Sentence 44: About Microsoft
# Microsoft (Nasdaq “MSFT” @microsoft) enables digital transformation for the era of an intelligent cloud and an intelligent edge.
# Sentence 45: Its mission is to empower every person and every organization on the planet to achieve more.
#
#
# Sentence 46: About Nuance Communications, Inc.
# Nuance Communications (NASDAQ: NUAN) is a technology pioneer with market leadership in conversational AI and ambient intelligence.
# Sentence 47: A full-service partner trusted by 77 percent of U.S. hospitals and 85 percent of the Fortune 100 companies worldwide, Nuance creates intuitive solutions that amplify people’s ability to help others.
#
#
# Sentence 48: For more information, press only:
#
# Microsoft Media Relations, WE Communications, (425) 638-7777, rrt@we-worldwide.com
#
# Note to editors: For more information, news and perspectives from Microsoft, please visit the Microsoft News Center at http://news.microsoft.com.
# Sentence 49: Web links, telephone numbers and titles were correct at time of publication but may have changed.
# Sentence 50: For additional assistance, journalists and analysts may contact Microsoft’s Rapid Response Team or other appropriate contacts listed at https://news.microsoft.com/microsoft-public-relations-contacts.
#
#
# Sentence 51: Trademark reference: Nuance and the Nuance logo are registered trademarks or trademarks of Nuance Communications, Inc. or its affiliates in the United States and/or other countries.
# Sentence 52: All other trademarks
#
# Named Entities:
# Pune: GPE
# India: GPE
# Sept. 13, 2022: DATE
# GLOBE NEWSWIRE: ORG
# USD 387.45 billion: MONEY
# 2022: DATE
# USD 1394.30 billion: MONEY
# 2029: DATE
# 20.1%: PERCENT
# the next several years: DATE
# Artificial Intelligence Market Forecast: WORK_OF_ART
# 2022-2029: DATE
# USD 328.34 billion: MONEY
# 2021: DATE
# Microsoft: ORG
# April 12, 2021 |: DATE
# Microsoft News Center
#
# Share on Facebook: ORG
# Microsoft: ORG
# REDMOND: GPE
# Wash.: GPE
# BURLINGTON: GPE
# Mass.: GPE
# April 12, 2021: DATE
# Microsoft Corp: ORG
# Nuance Communications, Inc.: ORG
# today: DATE
# Microsoft: ORG
# 56.00: MONEY
# 23%: PERCENT
# Friday, April 9: DATE
# $19.7 billion: MONEY
# Nuance: ORG
# AI: ORG
# decades: DATE
# Mark Benjamin: PERSON
# Scott Guthrie: PERSON
# Cloud & AI: ORG
# Microsoft: ORG
# this calendar year: DATE
# Microsoft: ORG
# Healthcare: ORG
# 2020: DATE
# Today: DATE
# Microsoft: ORG
# the Dragon Ambient: FAC
# Dragon Medical One: ORG
# PowerScribe: ORG
# SaaS: PRODUCT
# Microsoft Azure: ORG
# Electronic Health Records: ORG
# more than 55%: PERCENT
# 75%: PERCENT
# U.S.: GPE
# 77%: PERCENT
# U.S.: GPE
# Healthcare Cloud: ORG
# 37%: PERCENT
# Nuance: EVENT
# fiscal year 2020: DATE
# September 2020: DATE
# Microsoft: ORG
# 2019: DATE
# Healthcare: ORG
# Nuance: ORG
# Microsoft: ORG
# Microsoft: ORG
# Microsoft: ORG
# TAM: ORG
# TAM: ORG
# nearly $500 billion: MONEY
# Microsoft: ORG
# AI: ORG
# Satya Nadella: PERSON
# Microsoft: ORG
# healthcare: ORG
# Microsoft Cloud for: ORG
# Healthcare: ORG
# AI: ORG
# Interactive Voice Response: ORG
# Microsoft: ORG
# Azure: ORG
# Dynamics 365: ORG
# the past three years: DATE
# Nuance: ORG
# Mark Benjamin: PERSON
# Microsoft: ORG
# the Boards of Directors: ORG
# Microsoft: ORG
# Nuance: ORG
# Microsoft: ORG
# Nuance: ORG
# Microsoft: ORG
# Microsoft: ORG
# less than 1 percent: PERCENT
# fiscal year 2022: DATE
# fiscal year 2023: DATE
# Nadella: PERSON
# Benjamin: PERSON
# Guthrie: PERSON
# Microsoft: ORG
# Amy Hood: PERSON
# April 12, 2021: DATE
# 8 a.m.: TIME
# 201: CARDINAL
# 689: CARDINAL
# U.S.: GPE
# 877: CARDINAL
# 407: CARDINAL
# Goldman Sachs & Co. LLC: ORG
# Microsoft: ORG
# Simpson Thacher & Bartlett LLP: ORG
# Paul, Weiss,: ORG
# Rifkind, Wharton & Garrison LLP: ORG
# Microsoft
# Microsoft: ORG
# About Nuance Communications, Inc.
# Nuance Communications: ORG
# 77 percent: PERCENT
# U.S.: GPE
# 85 percent: PERCENT
# Fortune 100: CARDINAL
# Microsoft Media Relations: ORG
# WE Communications: ORG
# 425: CARDINAL
# 638: CARDINAL
# Microsoft: ORG
# the Microsoft News Center: ORG
# Microsoft: ORG
# Rapid Response Team: ORG
# Nuance Communications, Inc.: ORG
# the United States: GPE
#
# Explain POS and grammar:
#
# Token: Pune
# POS: PROPN
# Dependency: ROOT
# Explanation: proper noun
#
# Token: ,
# POS: PUNCT
# Dependency: punct
# Explanation: punctuation
#
# Token: India
# POS: PROPN
# Dependency: npadvmod
# Explanation: proper noun
#
# Token: ,
# POS: PUNCT
# Dependency: punct
# Explanation: punctuation
#
# Token: Sept.
# POS: PROPN
# Dependency: appos
# Explanation: proper noun
#
# Token: 13
# POS: NUM
# Dependency: nummod
# Explanation: numeral
#
# Token: ,
# POS: PUNCT
# Dependency: punct
# Explanation: punctuation
#
# Token: 2022
# POS: NUM
# Dependency: nummod
# Explanation: numeral
#
# Token: (
# POS: PUNCT
# Dependency: punct
# Explanation: punctuation
#
# Token: GLOBE
# POS: PROPN
# Dependency: compound
# Explanation: proper noun

# %%
process_doc(ai_forecast2_doc)
# Out:
# Tokens and POS:
# The: DET
# global: ADJ
# artificial: ADJ
# intelligence: NOUN
# market: NOUN
# size: NOUN
# was: AUX
# $: SYM
# 93.5: NUM
# billion: NUM
# in: ADP
# 2021: NUM
# .: PUNCT
# And: CCONJ
# according: VERB
# to: ADP
# Grand: PROPN
# View: PROPN
# Research: PROPN
# ,: PUNCT
# Inc.: PROPN
# ,: PUNCT
# it: PRON
# is: AUX
# projected: VERB
# to: PART
# expand: VERB
# at: ADP
# a: DET
# compound: ADJ
# annual: ADJ
# growth: NOUN
# rate: NOUN
# (: PUNCT
# CAGR: PROPN
# ): PUNCT
# of: ADP
# 38.1: NUM
# %: NOUN
# from: ADP
# 2022: NUM
# to: ADP
# 2030: NUM
# .: PUNCT
# The: DET
# market: NOUN
# is: AUX
# driven: VERB
# by: ADP
# the: DET
# increasing: VERB
# number: NOUN
# of: ADP
# connected: ADJ
# devices: NOUN
# ,: PUNCT
# growing: VERB
# demand: NOUN
# for: ADP
# personalized: ADJ
# services: NOUN
# ,: PUNCT
# and: CCONJ
# a: DET
# need: NOUN
# for: ADP
# real: ADJ
# -: PUNCT
# time: NOUN
# solutions: NOUN
# .: PUNCT
# Additionally: ADV
# ,: PUNCT
# advancements: NOUN
# in: ADP
# cloud: PROPN
# computing: NOUN
# technology: PROPN
# ,: PUNCT
# along: ADP
# with: ADP
# developments: NOUN
# in: ADP
# deep: ADJ
# learning: NOUN
# algorithms: NOUN
# ,: PUNCT
# have: AUX
# increased: VERB
# the: DET
# adoption: NOUN
# rate: NOUN
# of: ADP
# AI: PROPN
# .: PUNCT
#
#
# : SPACE
# Artificial: ADJ
# intelligence: NOUN
# growth: NOUN
# can: AUX
# be: AUX
# attributed: VERB
# to: ADP
# its: PRON
# widespread: ADJ
# application: NOUN
# across: ADP
# diverse: ADJ
# sectors: NOUN
# ,: PUNCT
# including: VERB
# healthcare: NOUN
# ,: PUNCT
# retail: NOUN
# ,: PUNCT
# and: CCONJ
# finance: NOUN
# .: PUNCT
# However: ADV
# ,: PUNCT
# some: DET
# challenges: NOUN
# must: AUX
# be: AUX
# addressed: VERB
# before: SCONJ
# it: PRON
# can: AUX
# reach: VERB
# mainstream: ADJ
# adoption: NOUN
# .: PUNCT
# These: DET
# hurdles: NOUN
# include: VERB
# high: ADJ
# infrastructure: NOUN
# costs: NOUN
# associated: VERB
# with: ADP
# implementing: VERB
# AI: PROPN
# systems: NOUN
# and: CCONJ
# a: DET
# lack: NOUN
# of: ADP
# awareness: NOUN
# about: ADP
# these: DET
# technologies: NOUN
# among: ADP
# businesses: NOUN
# that: PRON
# could: AUX
# benefit: VERB
# from: ADP
# them: PRON
# .: PUNCT
#
#
# : SPACE
# The: DET
# artificial: ADJ
# intelligence: NOUN
# market: NOUN
# is: AUX
# segmented: VERB
# based: VERB
# on: ADP
# product: NOUN
# type: NOUN
# ,: PUNCT
# application: NOUN
# ,: PUNCT
# and: CCONJ
# region: NOUN
# .: PUNCT
# Based: VERB
# on: ADP
# product: NOUN
# type: NOUN
# ,: PUNCT
# the: DET
# market: NOUN
# has: AUX
# been: AUX
# subdivided: VERB
# into: ADP
# service: NOUN
# robots: NOUN
# and: CCONJ
# software: NOUN
# .: PUNCT
# The: DET
# services: NOUN
# portion: NOUN
# accounted: VERB
# for: ADP
# around: ADP
# 66: NUM
# %: NOUN
# share: NOUN
# in: ADP
# 2016: NUM
# .: PUNCT
# Based: VERB
# on: ADP
# application: NOUN
# ,: PUNCT
# AI: PROPN
# has: AUX
# segmented: VERB
# into: ADP
# healthcare: NOUN
# and: CCONJ
# life: NOUN
# sciences: NOUN
# ;: PUNCT
# manufacturing: NOUN
# and: CCONJ
# logistics: NOUN
# ;: PUNCT
# energy: NOUN
# and: CCONJ
# utilities: NOUN
# ;: PUNCT
# banking: NOUN
# ,: PUNCT
# financial: ADJ
# services: NOUN
# ,: PUNCT
# and: CCONJ
# insurance: NOUN
# (: PUNCT
# BFSI: NOUN
# ): PUNCT
# ;: PUNCT
# process: NOUN
# manufacturing: NOUN
# industries: NOUN
# ;: PUNCT
# retail: NOUN
# and: CCONJ
# eCommerce: PROPN
# ;: PUNCT
# and: CCONJ
# agriculture: NOUN
# and: CCONJ
# forestry: NOUN
# sectors: NOUN
# (: PUNCT
# agribusinesses: NOUN
# ): PUNCT
# .: PUNCT
#
#
# : SPACE
# The: DET
# healthcare: NOUN
# sector: NOUN
# holds: VERB
# significant: ADJ
# potential: NOUN
# for: ADP
# AI: PROPN
# across: ADP
# various: ADJ
# applications: NOUN
# .: PUNCT
# This: PRON
# includes: VERB
# medical: ADJ
# imaging: NOUN
# analysis: NOUN
# ,: PUNCT
# molecular: ADJ
# biology: NOUN
# research: NOUN
# ,: PUNCT
# and: CCONJ
# drug: NOUN
# discovery: NOUN
# .: PUNCT
# Additionally: ADV
# ,: PUNCT
# there: PRON
# are: VERB
# developments: NOUN
# in: ADP
# drug: NOUN
# optimization: NOUN
# through: ADP
# predictive: ADJ
# analytics: NOUN
# tools: NOUN
# provided: VERB
# by: ADP
# leading: VERB
# players: NOUN
# ,: PUNCT
# such: ADJ
# as: ADP
# NVIDIA: PROPN
# Corporation: PROPN
# (: PUNCT
# NVDA: PROPN
# ): PUNCT
# ,: PUNCT
# Intel: PROPN
# Corporation: PROPN
# (: PUNCT
# INTC: PROPN
# ): PUNCT
# ,: PUNCT
# Alphabet: PROPN
# Inc.: PROPN
# (: PUNCT
# GOOGL: PROPN
# ): PUNCT
# ,: PUNCT
# and: CCONJ
# Amazon: PROPN
# Web: PROPN
# Services: PROPN
# Inc.: PROPN
# (: PUNCT
# AMZN: PROPN
# ): PUNCT
# .: PUNCT
# This: PRON
# is: AUX
# primarily: ADV
# due: ADJ
# to: ADP
# their: PRON
# high: ADJ
# adoption: NOUN
# rate: NOUN
# among: ADP
# researchers: NOUN
# worldwide: ADV
# coupled: VERB
# with: ADP
# increasing: VERB
# demand: NOUN
# from: ADP
# patients: NOUN
# willing: ADJ
# to: PART
# pay: VERB
# extra: ADJ
# if: SCONJ
# provided: VERB
# better: ADJ
# care: NOUN
# due: ADP
# to: ADP
# side: NOUN
# effects: NOUN
# associated: VERB
# with: ADP
# traditional: ADJ
# treatment: NOUN
# methods: NOUN
# .: PUNCT
#
# : SPACE
# Artificial: PROPN
# Intelligence: PROPN
# Market: PROPN
# by: ADP
# Component: PROPN
# Analysis: PROPN
#
#
# : SPACE
# AI: PROPN
# market: NOUN
# analysis: NOUN
# can: AUX
# be: AUX
# segmented: VERB
# into: ADP
# hardware: NOUN
# ,: PUNCT
# software: NOUN
# ,: PUNCT
# and: CCONJ
# service: NOUN
# components: NOUN
# .: PUNCT
# The: DET
# hardware: NOUN
# segment: NOUN
# is: AUX
# expected: VERB
# to: PART
# grow: VERB
# at: ADP
# the: DET
# highest: ADJ
# CAGR: NOUN
# during: ADP
# the: DET
# forecast: NOUN
# period: NOUN
# .: PUNCT
# The: DET
# need: NOUN
# for: ADP
# AI: PROPN
# services: NOUN
# is: AUX
# projected: VERB
# to: PART
# rise: VERB
# as: ADP
# smart: ADJ
# solutions: NOUN
# such: ADJ
# as: ADP
# virtual: ADJ
# assistants: NOUN
# and: CCONJ
# personalized: VERB
# online: ADJ
# experiences: NOUN
# become: VERB
# more: ADV
# widely: ADV
# used: VERB
# .: PUNCT
# These: DET
# services: NOUN
# use: VERB
# AI: PROPN
# capabilities: NOUN
# to: PART
# improve: VERB
# business: NOUN
# operations: NOUN
# ,: PUNCT
# such: ADJ
# as: ADP
# creating: VERB
# automated: ADJ
# and: CCONJ
# accurate: ADJ
# sales: NOUN
# projections: NOUN
# based: VERB
# on: ADP
# client: NOUN
# interactions: NOUN
# and: CCONJ
# sales: NOUN
# data: NOUN
# .: PUNCT
#
# : SPACE
# Artificial: PROPN
# Intelligence: PROPN
# Market: PROPN
# by: ADP
# Technology: PROPN
#
#
# : SPACE
# There: PRON
# are: VERB
# many: ADJ
# different: ADJ
# types: NOUN
# of: ADP
# artificial: ADJ
# intelligence: NOUN
# ,: PUNCT
# so: SCONJ
# it: PRON
# can: AUX
# be: AUX
# difficult: ADJ
# to: PART
# understand: VERB
# the: DET
# market: NOUN
# without: ADP
# an: DET
# overview: NOUN
# of: ADP
# the: DET
# technology: NOUN
# .: PUNCT
# The: DET
# AI: PROPN
# market: NOUN
# is: AUX
# further: ADV
# segmented: VERB
# by: ADP
# technology: NOUN
# .: PUNCT
# Natural: ADJ
# language: NOUN
# processing: NOUN
# (: PUNCT
# NLP: PROPN
# ): PUNCT
# ,: PUNCT
# machine: NOUN
# learning: NOUN
# ,: PUNCT
# context: NOUN
# -: PUNCT
# aware: ADJ
# computing: NOUN
# ,: PUNCT
# computer: NOUN
# vision: NOUN
# ,: PUNCT
# and: CCONJ
# virtual: ADJ
# agents: NOUN
# are: AUX
# some: DET
# major: ADJ
# technologies: NOUN
# used: VERB
# in: ADP
# the: DET
# AI: PROPN
# market: NOUN
# .: PUNCT
#
#
# : SPACE
# NLP: PROPN
# enables: VERB
# a: DET
# system: NOUN
# to: PART
# understand: VERB
# human: ADJ
# language: NOUN
# through: ADP
# various: ADJ
# methods: NOUN
# like: ADP
# speech: NOUN
# recognition: NOUN
# and: CCONJ
# natural: ADJ
# language: NOUN
# understanding: NOUN
# .: PUNCT
# Machine: NOUN
# learning: NOUN
# refers: VERB
# to: ADP
# the: DET
# process: NOUN
# of: ADP
# developing: VERB
# an: DET
# algorithm: NOUN
# that: PRON
# can: AUX
# automatically: ADV
# learn: VERB
# from: ADP
# its: PRON
# experience: NOUN
# without: ADP
# being: AUX
# explicitly: ADV
# programmed: VERB
# .: PUNCT
# Context: NOUN
# -: PUNCT
# aware: ADJ
# computing: NOUN
# refers: VERB
# to: ADP
# systems: NOUN
# that: PRON
# adapt: VERB
# their: PRON
# behavior: NOUN
# according: VERB
# to: ADP
# their: PRON
# surroundings: NOUN
# or: CCONJ
# environment: NOUN
# ,: PUNCT
# such: ADJ
# as: ADP
# GPS: PROPN
# location: NOUN
# services: NOUN
# on: ADP
# smartphones: NOUN
# or: CCONJ
# self: NOUN
# -: PUNCT
# driving: VERB
# cars: NOUN
# .: PUNCT
#
#
# : SPACE
# Computer: NOUN
# vision: NOUN
# refers: VERB
# to: ADP
# techniques: NOUN
# used: VERB
# to: PART
# process: VERB
# images: NOUN
# for: ADP
# perception: NOUN
# tasks: NOUN
# ,: PUNCT
# such: ADJ
# as: ADP
# facial: ADJ
# recognition: NOUN
# ,: PUNCT
# which: PRON
# plays: VERB
# a: DET
# role: NOUN
# in: ADP
# self: NOUN
# -: PUNCT
# driving: VERB
# cars: NOUN
# that: PRON
# can: AUX
# detect: VERB
# pedestrians: NOUN
# at: ADP
# night: NOUN
# in: ADP
# low: ADJ
# visibility: NOUN
# conditions: NOUN
# .: PUNCT
#
# : SPACE
# Artificial: PROPN
# Intelligence: PROPN
# Market: PROPN
# by: ADP
# End: PROPN
# -: PUNCT
# User: PROPN
# Industry: PROPN
#
#
# : SPACE
# The: DET
# AI: PROPN
# market: NOUN
# is: AUX
# segmented: VERB
# by: ADP
# end: NOUN
# -: PUNCT
# user: NOUN
# industry: NOUN
# into: ADP
# retail: NOUN
# ,: PUNCT
# healthcare: NOUN
# and: CCONJ
# life: NOUN
# sciences: NOUN
# ,: PUNCT
# automotive: NOUN
# and: CCONJ
# transportation: NOUN
# ,: PUNCT
# BFSI: NOUN
# ,: PUNCT
# consumer: NOUN
# goods: NOUN
# and: CCONJ
# retail: NOUN
# ,: PUNCT
# manufacturing: NOUN
# ,: PUNCT
# media: NOUN
# and: CCONJ
# entertainment: NOUN
# ,: PUNCT
# agriculture: NOUN
# and: CCONJ
# food: NOUN
# ,: PUNCT
# and: CCONJ
# energy: NOUN
# and: CCONJ
# utilities: NOUN
# .: PUNCT
#
#
# : SPACE
# The: DET
# retail: ADJ
# sector: NOUN
# accounted: VERB
# for: ADP
# one: NUM
# of: ADP
# the: DET
# largest: ADJ
# shares: NOUN
# of: ADP
# the: DET
# AI: PROPN
# market: NOUN
# in: ADP
# 2020: NUM
# .: PUNCT
# This: PRON
# can: AUX
# be: AUX
# attributed: VERB
# to: ADP
# the: DET
# rise: NOUN
# in: ADP
# smartphone: NOUN
# usage: NOUN
# across: ADP
# the: DET
# globe: NOUN
# ,: PUNCT
# as: ADV
# well: ADV
# as: ADP
# an: DET
# increase: NOUN
# in: ADP
# the: DET
# use: NOUN
# of: ADP
# smart: ADJ
# devices: NOUN
# .: PUNCT
# Smartphones: NOUN
# have: AUX
# also: ADV
# increased: VERB
# the: DET
# demand: NOUN
# for: ADP
# mobile: ADJ
# commerce: NOUN
# platforms: NOUN
# ,: PUNCT
# such: ADJ
# as: ADP
# the: DET
# customized: VERB
# CoverGirl: PROPN
# app: NOUN
# .: PUNCT
# The: DET
# app: NOUN
# employs: VERB
# predictive: ADJ
# analytics: NOUN
# software: NOUN
# and: CCONJ
# applies: VERB
# real: ADJ
# -: PUNCT
# time: NOUN
# data: NOUN
# to: PART
# deliver: VERB
# personalized: ADJ
# experiences: NOUN
# to: ADP
# customers: NOUN
# based: VERB
# on: ADP
# their: PRON
# preferences: NOUN
# .: PUNCT
#
#
# : SPACE
# The: DET
# automotive: ADJ
# industry: NOUN
# also: ADV
# accounted: VERB
# for: ADP
# a: DET
# sizable: ADJ
# share: NOUN
# of: ADP
# the: DET
# global: ADJ
# artificial: ADJ
# intelligence: NOUN
# market: NOUN
# .: PUNCT
# This: PRON
# can: AUX
# be: AUX
# attributed: VERB
# to: ADP
# the: DET
# increased: VERB
# adoption: NOUN
# of: ADP
# self: NOUN
# -: PUNCT
# driving: VERB
# vehicles: NOUN
# globally: ADV
# .: PUNCT
# This: PRON
# has: AUX
# also: ADV
# led: VERB
# to: ADP
# more: ADJ
# adoption: NOUN
# of: ADP
# intelligent: ADJ
# transportation: NOUN
# systems: NOUN
# ,: PUNCT
# such: ADJ
# as: ADP
# electronic: ADJ
# toll: NOUN
# collection: NOUN
# ,: PUNCT
# ramp: NOUN
# meters: NOUN
# ,: PUNCT
# red: ADJ
# light: NOUN
# cameras: NOUN
# ,: PUNCT
# traffic: NOUN
# signal: NOUN
# coordination: NOUN
# ,: PUNCT
# transit: NOUN
# signal: NOUN
# priority: NOUN
# ,: PUNCT
# and: CCONJ
# traveler: NOUN
# information: NOUN
# systems: NOUN
# .: PUNCT
#
#
# : SPACE
# The: DET
# healthcare: NOUN
# and: CCONJ
# life: NOUN
# sciences: NOUN
# segment: NOUN
# is: AUX
# expected: VERB
# to: PART
# grow: VERB
# at: ADP
# the: DET
# highest: ADJ
# rate: NOUN
# in: ADP
# the: DET
# next: ADJ
# few: ADJ
# years: NOUN
# ,: PUNCT
# owing: VERB
# to: ADP
# the: DET
# increasing: VERB
# demand: NOUN
# for: ADP
# personalized: ADJ
# medicine: NOUN
# solutions: NOUN
# .: PUNCT
# As: SCONJ
# it: PRON
# is: AUX
# based: VERB
# on: ADP
# each: DET
# patient: NOUN
# ’s: PART
# unique: ADJ
# genetic: ADJ
# composition: NOUN
# ,: PUNCT
# personalized: ADJ
# medicine: NOUN
# is: AUX
# beginning: VERB
# to: PART
# transcend: VERB
# standard: ADJ
# medicine: NOUN
# ’s: PART
# limits: NOUN
# .: PUNCT
# For: ADP
# example: NOUN
# ,: PUNCT
# personalized: ADJ
# treatment: NOUN
# for: ADP
# diabetes: NOUN
# (: PUNCT
# PMFD: PROPN
# ): PUNCT
# uses: VERB
# knowledge: NOUN
# about: ADP
# a: DET
# person: NOUN
# ’s: PART
# genetic: ADJ
# composition: NOUN
# to: PART
# modify: VERB
# tactics: NOUN
# for: ADP
# preventing: NOUN
# ,: PUNCT
# diagnosing: NOUN
# ,: PUNCT
# treating: NOUN
# ,: PUNCT
# or: CCONJ
# monitoring: VERB
# diabetes: NOUN
# .: PUNCT
#
# : SPACE
# COVID-19: PROPN
# Impact: PROPN
# on: ADP
# Global: PROPN
# Al: PROPN
# Market: PROPN
#
#
# : SPACE
# As: ADP
# businesses: NOUN
# and: CCONJ
# other: ADJ
# organizations: NOUN
# worldwide: ADV
# have: AUX
# been: AUX
# dealing: VERB
# with: ADP
# the: DET
# consequences: NOUN
# of: ADP
# the: DET
# ongoing: ADJ
# COVID-19: PROPN
# pandemic: NOUN
# and: CCONJ
# plan: NOUN
# for: ADP
# a: DET
# post: ADJ
# -: ADJ
# pandemic: ADJ
# future: NOUN
# ,: PUNCT
# one: NUM
# critical: ADJ
# question: NOUN
# arises: VERB
# :: PUNCT
# how: SCONJ
# much: ADJ
# did: AUX
# COVID: PROPN
# affect: VERB
# the: DET
# AI: PROPN
# market: NOUN
# globally: ADV
# ?: PUNCT
#
#
# : SPACE
# “: PUNCT
# AI: PROPN
# is: AUX
# still: ADV
# in: ADP
# the: DET
# early: ADJ
# stages: NOUN
# of: ADP
# a: DET
# long: ADJ
# secular: ADJ
# growth: NOUN
# trend: NOUN
# ,: PUNCT
# ”: PUNCT
# says: VERB
# Erik: PROPN
# Brynjolfsson: PROPN
# ,: PUNCT
# professor: NOUN
# and: CCONJ
# senior: ADJ
# fellow: NOUN
# at: ADP
# Stanford: PROPN
# Institute: PROPN
# for: ADP
# Human: PROPN
# -: PUNCT
# Centered: PROPN
# AI: PROPN
# (: PUNCT
# HAI: PROPN
# ): PUNCT
# and: CCONJ
# director: NOUN
# of: ADP
# the: DET
# Stanford: PROPN
# Digital: PROPN
# Economy: PROPN
# Lab: PROPN
# .: PUNCT
# “: PUNCT
# But: CCONJ
# the: DET
# pandemic: NOUN
# is: AUX
# accelerating: VERB
# that: DET
# trend: NOUN
# ,: PUNCT
# especially: ADV
# in: ADP
# areas: NOUN
# like: ADP
# biotech: PROPN
# ,: PUNCT
# including: VERB
# drug: NOUN
# design: NOUN
# and: CCONJ
# discovery: NOUN
# .: PUNCT
# ”: PUNCT
# According: VERB
# to: ADP
# an: DET
# annual: ADJ
# study: NOUN
# on: ADP
# AI: PROPN
# and: CCONJ
# its: PRON
# impact: NOUN
# and: CCONJ
# progress: NOUN
# developed: VERB
# by: ADP
# Stanford: PROPN
# HAI: PROPN
# ,: PUNCT
# hiring: NOUN
# ,: PUNCT
# investment: NOUN
# ,: PUNCT
# and: CCONJ
# adoption: NOUN
# of: ADP
# AI: PROPN
# grew: VERB
# in: ADP
# 2020: NUM
# ,: PUNCT
# reflecting: VERB
# long: ADJ
# -: PUNCT
# term: NOUN
# business: NOUN
# trends: NOUN
# that: PRON
# would: AUX
# likely: ADV
# outlive: VERB
# the: DET
# pandemic: NOUN
# ’s: PART
# effects: NOUN
# .: PUNCT
#
#
# : SPACE
# During: ADP
# the: DET
# pandemic: NOUN
# ,: PUNCT
# investment: NOUN
# in: ADP
# AI: PROPN
# -: PUNCT
# focused: VERB
# private: ADJ
# enterprises: NOUN
# remained: VERB
# substantial: ADJ
# ,: PUNCT
# particularly: ADV
# in: ADP
# fields: NOUN
# tied: VERB
# to: ADP
# COVID: PROPN
# .: PUNCT
# Additionally: ADV
# ,: PUNCT
# when: SCONJ
# it: PRON
# comes: VERB
# to: ADP
# company: NOUN
# investments: NOUN
# in: ADP
# AI: PROPN
# capabilities: NOUN
# ,: PUNCT
# Brynjolfsson: PROPN
# says: VERB
# ,: PUNCT
# “: PUNCT
# while: SCONJ
# some: DET
# firms: NOUN
# decreased: VERB
# their: PRON
# investments: NOUN
# ,: PUNCT
# slightly: ADV
# more: ADJ
# firms: NOUN
# increased: VERB
# their: PRON
# investments: NOUN
# .: PUNCT
# ”: PUNCT
# He: PRON
# also: ADV
# highlights: VERB
# that: SCONJ
# the: DET
# biggest: ADJ
# increases: NOUN
# in: ADP
# investment: NOUN
# were: AUX
# made: VERB
# in: ADP
# healthcare: NOUN
# and: CCONJ
# pharma: NOUN
# .: PUNCT
#
#
# : SPACE
# However: ADV
# ,: PUNCT
# sectors: NOUN
# beyond: ADP
# healthcare: NOUN
# also: ADV
# showcased: VERB
# increased: VERB
# investment: NOUN
# in: ADP
# AI: PROPN
# for: ADP
# the: DET
# long: ADJ
# term: NOUN
# ,: PUNCT
# like: ADP
# education: NOUN
# ,: PUNCT
# retail: NOUN
# ,: PUNCT
# and: CCONJ
# the: DET
# automotive: ADJ
# industry: NOUN
# .: PUNCT
# As: ADP
# a: DET
# result: NOUN
# ,: PUNCT
# the: DET
# AI: PROPN
# industry: NOUN
# saw: VERB
# substantial: ADJ
# hiring: VERB
# growth: NOUN
# during: ADP
# COVID-19: PROPN
# .: PUNCT
# Manufacturing: NOUN
# and: CCONJ
# retail: NOUN
# are: AUX
# expected: VERB
# to: PART
# grow: VERB
# in: ADP
# hiring: VERB
# AI: PROPN
# -: PUNCT
# related: VERB
# jobs: NOUN
# ,: PUNCT
# thus: ADV
# catching: VERB
# up: ADP
# with: ADP
# healthcare: NOUN
# ,: PUNCT
# finance: NOUN
# ,: PUNCT
# and: CCONJ
# other: ADJ
# service: NOUN
# industries: NOUN
# that: PRON
# have: AUX
# been: AUX
# strong: ADJ
# early: ADJ
# adopters: NOUN
# of: ADP
# AI: PROPN
# .: PUNCT
#
# : SPACE
# Growing: VERB
# Investments: PROPN
# in: ADP
# Artificial: PROPN
# Intelligence: PROPN
# Systems: PROPN
#
#
# : SPACE
# According: VERB
# to: ADP
# Tortoise: PROPN
# Intelligence: PROPN
# ,: PUNCT
# global: ADJ
# investment: NOUN
# in: ADP
# AI: PROPN
# firms: NOUN
# has: AUX
# surged: VERB
# by: ADP
# 115: NUM
# %: NOUN
# since: SCONJ
# 2020: NUM
# ,: PUNCT
# the: DET
# biggest: ADJ
# year: NOUN
# -: PUNCT
# over: ADP
# -: PUNCT
# year: NOUN
# increase: NOUN
# in: ADP
# AI: PROPN
# investment: NOUN
# in: ADP
# at: ADV
# least: ADV
# two: NUM
# decades: NOUN
# .: PUNCT
#
#
# : SPACE
# Investments: NOUN
# in: ADP
# AI: PROPN
# are: AUX
# increasing: VERB
# across: ADP
# all: DET
# parts: NOUN
# of: ADP
# the: DET
# world: NOUN
# ,: PUNCT
# and: CCONJ
# there: PRON
# are: VERB
# many: ADJ
# examples: NOUN
# where: SCONJ
# countries: NOUN
# have: AUX
# been: AUX
# making: VERB
# significant: ADJ
# investments: NOUN
# in: ADP
# technology: NOUN
# .: PUNCT
# For: ADP
# example: NOUN
# ,: PUNCT
# China: PROPN
# has: AUX
# invested: VERB
# heavily: ADV
# in: ADP
# developing: VERB
# AI: PROPN
# capabilities: NOUN
# through: ADP
# its: PRON
# national: ADJ
# strategy: NOUN
# and: CCONJ
# has: AUX
# made: VERB
# it: PRON
# one: NUM
# of: ADP
# its: PRON
# top: ADJ
# priorities: NOUN
# for: ADP
# economic: ADJ
# development: NOUN
# .: PUNCT
# The: DET
# European: PROPN
# Union: PROPN
# (: PUNCT
# EU: PROPN
# ): PUNCT
# has: AUX
# also: ADV
# created: VERB
# an: DET
# initiative: NOUN
# called: VERB
# Horizon: PROPN
# 2020: NUM
# that: PRON
# aims: VERB
# to: PART
# invest: VERB
# €: SYM
# 1: NUM
# billion: NUM
# per: ADP
# year: NOUN
# into: ADP
# research: NOUN
# projects: NOUN
# related: VERB
# to: ADP
# future: ADJ
# technologies: NOUN
# ,: PUNCT
# such: ADJ
# as: ADP
# artificial: ADJ
# intelligence: NOUN
# ,: PUNCT
# robotics: NOUN
# ,: PUNCT
# nanotechnology: NOUN
# ,: PUNCT
# and: CCONJ
# advanced: ADJ
# manufacturing: NOUN
# processes: NOUN
# .: PUNCT
#
# : SPACE
# Regional: ADJ
# Insights: NOUN
#
#
# : SPACE
# In: ADP
# 2021: NUM
# ,: PUNCT
# North: PROPN
# America: PROPN
# dominated: VERB
# the: DET
# AI: PROPN
# market: NOUN
# and: CCONJ
# accounted: VERB
# for: ADP
# a: DET
# revenue: NOUN
# share: NOUN
# of: ADP
# more: ADJ
# than: ADP
# 42: NUM
# %: NOUN
# .: PUNCT
# This: DET
# significant: ADJ
# proportion: NOUN
# is: AUX
# related: VERB
# to: ADP
# government: NOUN
# measures: NOUN
# that: PRON
# stimulate: VERB
# the: DET
# deployment: NOUN
# of: ADP
# AI: PROPN
# across: ADP
# a: DET
# variety: NOUN
# of: ADP
# businesses: NOUN
# .: PUNCT
# For: ADP
# instance: NOUN
# ,: PUNCT
# President: PROPN
# Trump: PROPN
# unveiled: VERB
# the: DET
# American: PROPN
# AI: PROPN
# Initiative: PROPN
# in: ADP
# February: PROPN
# 2019: NUM
# as: ADP
# the: DET
# nation: NOUN
# ’s: PART
# strategy: NOUN
# for: ADP
# advancing: VERB
# leadership: NOUN
# in: ADP
# artificial: ADJ
# intelligence: NOUN
# .: PUNCT
# As: ADP
# part: NOUN
# of: ADP
# this: DET
# endeavor: NOUN
# ,: PUNCT
# federal: ADJ
# authorities: NOUN
# bolstered: VERB
# public: ADJ
# confidence: NOUN
# in: ADP
# AI: PROPN
# -: PUNCT
# based: VERB
# systems: NOUN
# by: ADP
# setting: VERB
# rules: NOUN
# for: ADP
# their: PRON
# development: NOUN
# and: CCONJ
# real: ADJ
# -: PUNCT
# world: NOUN
# use: NOUN
# across: ADP
# various: ADJ
# industries: NOUN
# .: PUNCT
#
#
# : SPACE
# As: ADP
# such: ADJ
# ,: PUNCT
# North: PROPN
# America: PROPN
# is: AUX
# expected: VERB
# to: PART
# hold: VERB
# the: DET
# largest: ADJ
# share: NOUN
# of: ADP
# the: DET
# AI: PROPN
# market: NOUN
# during: ADP
# the: DET
# coming: VERB
# years: NOUN
# .: PUNCT
# North: PROPN
# America: PROPN
# is: AUX
# home: NOUN
# to: ADP
# several: ADJ
# technology: NOUN
# companies: NOUN
# and: CCONJ
# has: VERB
# a: DET
# strong: ADJ
# network: NOUN
# of: ADP
# research: NOUN
# and: CCONJ
# development: NOUN
# centers: NOUN
# in: ADP
# this: DET
# domain: NOUN
# .: PUNCT
# The: DET
# U.S.: PROPN
# ,: PUNCT
# Canada: PROPN
# ,: PUNCT
# and: CCONJ
# Mexico: PROPN
# are: AUX
# major: ADJ
# markets: NOUN
# for: ADP
# AI: PROPN
# -: PUNCT
# based: VERB
# services: NOUN
# and: CCONJ
# technologies: NOUN
# .: PUNCT
# Furthermore: ADV
# ,: PUNCT
# North: PROPN
# America: PROPN
# accounts: VERB
# for: ADP
# many: ADJ
# global: ADJ
# venture: NOUN
# capital: NOUN
# investments: NOUN
# in: ADP
# AI: PROPN
# startups: NOUN
# ,: PUNCT
# which: PRON
# indicates: VERB
# its: PRON
# growing: VERB
# adoption: NOUN
# rate: NOUN
# by: ADP
# businesses: NOUN
# worldwide: ADV
# .: PUNCT
#
#
# : SPACE
# In: ADP
# Asia: PROPN
# and: CCONJ
# the: DET
# Pacific: PROPN
# ,: PUNCT
# the: DET
# market: NOUN
# is: AUX
# expected: VERB
# to: PART
# grow: VERB
# at: ADP
# a: DET
# substantial: ADJ
# CAGR: NOUN
# over: ADP
# the: DET
# next: ADJ
# few: ADJ
# years: NOUN
# .: PUNCT
# This: DET
# expansion: NOUN
# is: AUX
# attributable: ADJ
# to: ADP
# the: DET
# increased: VERB
# investments: NOUN
# in: ADP
# artificial: ADJ
# intelligence: NOUN
# .: PUNCT
# For: ADP
# example: NOUN
# ,: PUNCT
# Baidu: PROPN
# ,: PUNCT
# Inc.: PROPN
# ,: PUNCT
# a: DET
# Chinese: ADJ
# Internet: NOUN
# behemoth: NOUN
# ,: PUNCT
# stated: VERB
# in: ADP
# April: PROPN
# 2018: NUM
# that: SCONJ
# it: PRON
# had: AUX
# entered: VERB
# into: ADP
# definitive: ADJ
# agreements: NOUN
# with: ADP
# investors: NOUN
# about: ADP
# the: DET
# sale: NOUN
# of: ADP
# its: PRON
# financial: ADJ
# services: NOUN
# group: NOUN
# ,: PUNCT
# which: PRON
# provides: VERB
# wealth: NOUN
# management: NOUN
# ,: PUNCT
# consumer: NOUN
# lending: NOUN
# ,: PUNCT
# and: CCONJ
# other: ADJ
# commercial: ADJ
# services: NOUN
# .: PUNCT
# In: ADP
# addition: NOUN
# ,: PUNCT
# the: DET
# increasing: VERB
# number: NOUN
# of: ADP
# AI: PROPN
# startups: NOUN
# in: ADP
# the: DET
# region: NOUN
# is: AUX
# accelerating: VERB
# the: DET
# implementation: NOUN
# of: ADP
# AI: PROPN
# to: PART
# enhance: VERB
# operational: ADJ
# efficiency: NOUN
# and: CCONJ
# enable: VERB
# process: NOUN
# automation: NOUN
# .: PUNCT
#
#
# : SPACE
# ​​Additionally: ADV
# ,: PUNCT
# the: DET
# region: NOUN
# is: AUX
# expected: VERB
# to: PART
# continue: VERB
# growing: VERB
# in: ADP
# the: DET
# healthcare: NOUN
# ,: PUNCT
# manufacturing: NOUN
# ,: PUNCT
# finance: NOUN
# ,: PUNCT
# and: CCONJ
# retail: ADJ
# sectors: NOUN
# .: PUNCT
# This: PRON
# is: AUX
# due: ADJ
# to: ADP
# increased: VERB
# revenue: NOUN
# generated: VERB
# from: ADP
# the: DET
# sale: NOUN
# of: ADP
# AI: PROPN
# products: NOUN
# and: CCONJ
#
# Sentences:
# Sentence 1: The global artificial intelligence market size was $93.5 billion in 2021.
# Sentence 2: And according to Grand View Research, Inc., it is projected to expand at a compound annual growth rate (CAGR) of 38.1% from 2022 to 2030.
# Sentence 3: The market is driven by the increasing number of connected devices, growing demand for personalized services, and a need for real-time solutions.
# Sentence 4: Additionally, advancements in cloud computing technology, along with developments in deep learning algorithms, have increased the adoption rate of AI.
#
# Artificial intelligence growth can be attributed to its widespread application across diverse sectors, including healthcare, retail, and finance.
# Sentence 5: However, some challenges must be addressed before it can reach mainstream adoption.
# Sentence 6: These hurdles include high infrastructure costs associated with implementing AI systems and a lack of awareness about these technologies among businesses that could benefit from them.
#
#
# Sentence 7: The artificial intelligence market is segmented based on product type, application, and region.
# Sentence 8: Based on product type, the market has been subdivided into service robots and software.
# Sentence 9: The services portion accounted for around 66% share in 2016.
# Sentence 10: Based on application, AI has segmented into healthcare and life sciences; manufacturing and logistics; energy and utilities; banking, financial services, and insurance (BFSI); process manufacturing industries; retail and eCommerce; and agriculture and forestry sectors (agribusinesses).
#
#
# Sentence 11: The healthcare sector holds significant potential for AI across various applications.
# Sentence 12: This includes medical imaging analysis, molecular biology research, and drug discovery.
# Sentence 13: Additionally, there are developments in drug optimization through predictive analytics tools provided by leading players, such as NVIDIA Corporation (NVDA), Intel Corporation (INTC), Alphabet Inc. (GOOGL), and Amazon Web Services Inc. (AMZN).
# Sentence 14: This is primarily due to their high adoption rate among researchers worldwide coupled with increasing demand from patients willing to pay extra if provided better care due to side effects associated with traditional treatment methods.
#
# Sentence 15: Artificial Intelligence Market by Component Analysis
#
# AI market analysis can be segmented into hardware, software, and service components.
# Sentence 16: The hardware segment is expected to grow at the highest CAGR during the forecast period.
# Sentence 17: The need for AI services is projected to rise as smart solutions such as virtual assistants and personalized online experiences become more widely used.
# Sentence 18: These services use AI capabilities to improve business operations, such as creating automated and accurate sales projections based on client interactions and sales data.
#
# Sentence 19: Artificial Intelligence Market by Technology
#
# There are many different types of artificial intelligence, so it can be difficult to understand the market without an overview of the technology.
# Sentence 20: The AI market is further segmented by technology.
# Sentence 21: Natural language processing (NLP), machine learning, context-aware computing, computer vision, and virtual agents are some major technologies used in the AI market.
#
#
# Sentence 22: NLP enables a system to understand human language through various methods like speech recognition and natural language understanding.
# Sentence 23: Machine learning refers to the process of developing an algorithm that can automatically learn from its experience without being explicitly programmed.
# Sentence 24: Context-aware computing refers to systems that adapt their behavior according to their surroundings or environment, such as GPS location services on smartphones or self-driving cars.
#
#
# Sentence 25: Computer vision refers to techniques used to process images for perception tasks, such as facial recognition, which plays a role in self-driving cars that can detect pedestrians at night in low visibility conditions.
#
# Sentence 26: Artificial Intelligence Market by End-User Industry
#
# The AI market is segmented by end-user industry into retail, healthcare and life sciences, automotive and transportation, BFSI, consumer goods and retail, manufacturing, media and entertainment, agriculture and food, and energy and utilities.
#
#
# Sentence 27: The retail sector accounted for one of the largest shares of the AI market in 2020.
# Sentence 28: This can be attributed to the rise in smartphone usage across the globe, as well as an increase in the use of smart devices.
# Sentence 29: Smartphones have also increased the demand for mobile commerce platforms, such as the customized CoverGirl app.
# Sentence 30: The app employs predictive analytics software and applies real-time data to deliver personalized experiences to customers based on their preferences.
#
#
# Sentence 31: The automotive industry also accounted for a sizable share of the global artificial intelligence market.
# Sentence 32: This can be attributed to the increased adoption of self-driving vehicles globally.
# Sentence 33: This has also led to more adoption of intelligent transportation systems, such as electronic toll collection, ramp meters, red light cameras, traffic signal coordination, transit signal priority, and traveler information systems.
#
#
# Sentence 34: The healthcare and life sciences segment is expected to grow at the highest rate in the next few years, owing to the increasing demand for personalized medicine solutions.
# Sentence 35: As it is based on each patient’s unique genetic composition, personalized medicine is beginning to transcend standard medicine’s limits.
# Sentence 36: For example, personalized treatment for diabetes (PMFD) uses knowledge about a person’s genetic composition to modify tactics for preventing, diagnosing, treating, or monitoring diabetes.
#
# Sentence 37: COVID-19 Impact on Global Al Market
#
# As businesses and other organizations worldwide have been dealing with the consequences of the ongoing COVID-19 pandemic and plan for a post-pandemic future, one critical question arises: how much did COVID affect the AI market globally?
#
#
# Sentence 38: “AI is still in the early stages of a long secular growth trend,” says Erik Brynjolfsson, professor and senior fellow at Stanford Institute for Human-Centered AI (HAI) and director of the Stanford Digital Economy Lab.
# Sentence 39: “But the pandemic is accelerating that trend, especially in areas like biotech, including drug design and discovery.”
# Sentence 40: According to an annual study on AI and its impact and progress developed by Stanford HAI, hiring, investment, and adoption of AI grew in 2020, reflecting long-term business trends that would likely outlive the pandemic’s effects.
#
#
# Sentence 41: During the pandemic, investment in AI-focused private enterprises remained substantial, particularly in fields tied to COVID.
# Sentence 42: Additionally, when it comes to company investments in AI capabilities, Brynjolfsson says, “while some firms decreased their investments, slightly more firms increased their investments.”
# Sentence 43: He also highlights that the biggest increases in investment were made in healthcare and pharma.
#
#
# Sentence 44: However, sectors beyond healthcare also showcased increased investment in AI for the long term, like education, retail, and the automotive industry.
# Sentence 45: As a result, the AI industry saw substantial hiring growth during COVID-19.
# Sentence 46: Manufacturing and retail are expected to grow in hiring AI-related jobs, thus catching up with healthcare, finance, and other service industries that have been strong early adopters of AI.
# Growing Investments in Artificial Intelligence Systems
#
#
# Sentence 47: According to Tortoise Intelligence, global investment in AI firms has surged by 115% since 2020, the biggest year-over-year increase in AI investment in at least two decades.
#
#
# Sentence 48: Investments in AI are increasing across all parts of the world, and there are many examples where countries have been making significant investments in technology.
# Sentence 49: For example, China has invested heavily in developing AI capabilities through its national strategy and has made it one of its top priorities for economic development.
# Sentence 50: The European Union (EU) has also created an initiative called Horizon 2020 that aims to invest €1 billion per year into research projects related to future technologies, such as artificial intelligence, robotics, nanotechnology, and advanced manufacturing processes.
#
# Sentence 51: Regional Insights
#
# In 2021, North America dominated the AI market and accounted for a revenue share of more than 42%.
# Sentence 52: This significant proportion is related to government measures that stimulate the deployment of AI across a variety of businesses.
# Sentence 53: For instance, President Trump unveiled the American AI Initiative in February 2019 as the nation’s strategy for advancing leadership in artificial intelligence.
# Sentence 54: As part of this endeavor, federal authorities bolstered public confidence in AI-based systems by setting rules for their development and real-world use across various industries.
#
#
# Sentence 55: As such, North America is expected to hold the largest share of the AI market during the coming years.
# Sentence 56: North America is home to several technology companies and has a strong network of research and development centers in this domain.
# Sentence 57: The U.S., Canada, and Mexico are major markets for AI-based services and technologies.
# Sentence 58: Furthermore, North America accounts for many global venture capital investments in AI startups, which indicates its growing adoption rate by businesses worldwide.
#
#
# Sentence 59: In Asia and the Pacific, the market is expected to grow at a substantial CAGR over the next few years.
# Sentence 60: This expansion is attributable to the increased investments in artificial intelligence.
# Sentence 61: For example, Baidu, Inc., a Chinese Internet behemoth, stated in April 2018 that it had entered into definitive agreements with investors about the sale of its financial services group, which provides wealth management, consumer lending, and other commercial services.
# Sentence 62: In addition, the increasing number of AI startups in the region is accelerating the implementation of AI to enhance operational efficiency and enable process automation.
#
#
# Sentence 63: ​​Additionally, the region is expected to continue growing in the healthcare, manufacturing, finance, and retail sectors.
# Sentence 64: This is due to increased revenue generated from the sale of AI products and
#
# Named Entities:
# $93.5 billion: MONEY
# 2021: DATE
# Grand View Research, Inc.: ORG
# 38.1%: PERCENT
# 2022: DATE
# 2030: DATE
# AI: ORG
# AI: ORG
# around 66%: PERCENT
# 2016: DATE
# AI: ORG
# NVIDIA Corporation: ORG
# NVDA: ORG
# Intel Corporation: ORG
# Alphabet Inc.: ORG
# Amazon Web Services Inc.: ORG
# AMZN: ORG
# Artificial Intelligence Market by Component Analysis: ORG
# Artificial Intelligence Market by Technology: ORG
# AI: ORG
# NLP: ORG
# AI: ORG
# NLP: ORG
# night: TIME
# Artificial Intelligence Market: ORG
# AI: ORG
# one: CARDINAL
# AI: ORG
# 2020: DATE
# CoverGirl: PRODUCT
# the next few years: DATE
# PMFD: ORG
# AI: ORG
# Erik Brynjolfsson: PERSON
# Stanford Institute for Human-Centered: ORG
# the Stanford Digital Economy Lab: ORG
# annual: DATE
# AI: ORG
# Stanford: ORG
# AI: ORG
# 2020: DATE
# Brynjolfsson: PERSON
# AI: ORG
# AI: ORG
# Growing Investments in: ORG
# Artificial Intelligence Systems: ORG
# Tortoise Intelligence: ORG
# 115%: PERCENT
# 2020: DATE
# the biggest year-over-year: DATE
# at least two decades: DATE
# China: GPE
# The European Union: ORG
# EU: ORG
# Horizon 2020: ORG
# €1 billion: MONEY
# 2021: DATE
# North America: LOC
# AI: ORG
# more than 42%: PERCENT
# Trump: PERSON
# American: NORP
# February 2019: DATE
# North America: LOC
# AI: ORG
# the coming years: DATE
# North America: LOC
# U.S.: GPE
# Canada: GPE
# Mexico: GPE
# North America: LOC
# Asia: LOC
# Pacific: LOC
# the next few years: DATE
# Baidu, Inc.: ORG
# Chinese: NORP
# April 2018: DATE
# AI: ORG
#
# Explain POS and grammar:
#
# Token: The
# POS: DET
# Dependency: det
# Explanation: determiner
#
# Token: global
# POS: ADJ
# Dependency: amod
# Explanation: adjective
#
# Token: artificial
# POS: ADJ
# Dependency: amod
# Explanation: adjective
#
# Token: intelligence
# POS: NOUN
# Dependency: compound
# Explanation: noun
#
# Token: market
# POS: NOUN
# Dependency: compound
# Explanation: noun
#
# Token: size
# POS: NOUN
# Dependency: nsubj
# Explanation: noun
#
# Token: was
# POS: AUX
# Dependency: ROOT
# Explanation: auxiliary
#
# Token: $
# POS: SYM
# Dependency: quantmod
# Explanation: symbol
#
# Token: 93.5
# POS: NUM
# Dependency: compound
# Explanation: numeral
#
# Token: billion
# POS: NUM
# Dependency: attr
# Explanation: numeral

# %%
patterns = [
    # Pattern for "Artificial Intelligence"
    [{"LOWER": "artificial"}, {"LOWER": "intelligence"}],

    # Pattern for "AI" followed by a verb
    [{"LOWER": "ai"}, {"POS": "VERB"}],

    # Pattern for numbers followed by %
    [{"LIKE_NUM": True}, {"TEXT": "%"}],

    # Pattern for company names (heuristic)
    [{"ENT_TYPE": "ORG"}]
]

# %%
pattern_matching_spacy_docs([ai_forecast1_doc, ai_forecast2_doc], patterns)
# Out:
# Matches for pattern [{'ENT_TYPE': 'ORG'}]:
# - 'GLOBE' found in document 1 in sentence: 'Pune, India, Sept. 13, 2022 (GLOBE NEWSWIRE) --'
#
# - 'NEWSWIRE' found in document 1 in sentence: 'Pune, India, Sept. 13, 2022 (GLOBE NEWSWIRE) --'
#
# - 'Microsoft' found in document 1 in sentence: 'Request a Sample Copy of the Research Report:
# https://www.fortunebusinessinsights.com/enquiry/request-sample-pdf/artificial-intelligence-market-100114
#
# Microsoft accelerates industry cloud strategy for healthcare with the acquisition of Nuance
#
# April 12, 2021 | Microsoft News Center
#
# Share on Facebook (opens new window)
# '
#
# - 'Microsoft' found in document 1 in sentence: 'Request a Sample Copy of the Research Report:
# https://www.fortunebusinessinsights.com/enquiry/request-sample-pdf/artificial-intelligence-market-100114
#
# Microsoft accelerates industry cloud strategy for healthcare with the acquisition of Nuance
#
# April 12, 2021 | Microsoft News Center
#
# Share on Facebook (opens new window)
# '
#
# - 'News' found in document 1 in sentence: 'Request a Sample Copy of the Research Report:
# https://www.fortunebusinessinsights.com/enquiry/request-sample-pdf/artificial-intelligence-market-100114
#
# Microsoft accelerates industry cloud strategy for healthcare with the acquisition of Nuance
#
# April 12, 2021 | Microsoft News Center
#
# Share on Facebook (opens new window)
# '
#
# - 'Center' found in document 1 in sentence: 'Request a Sample Copy of the Research Report:
# https://www.fortunebusinessinsights.com/enquiry/request-sample-pdf/artificial-intelligence-market-100114
#
# Microsoft accelerates industry cloud strategy for healthcare with the acquisition of Nuance
#
# April 12, 2021 | Microsoft News Center
#
# Share on Facebook (opens new window)
# '
#
# - '
#
# ' found in document 1 in sentence: 'Request a Sample Copy of the Research Report:
# https://www.fortunebusinessinsights.com/enquiry/request-sample-pdf/artificial-intelligence-market-100114
#
# Microsoft accelerates industry cloud strategy for healthcare with the acquisition of Nuance
#
# April 12, 2021 | Microsoft News Center
#
# Share on Facebook (opens new window)
# '
#
# - 'Share' found in document 1 in sentence: 'Request a Sample Copy of the Research Report:
# https://www.fortunebusinessinsights.com/enquiry/request-sample-pdf/artificial-intelligence-market-100114
#
# Microsoft accelerates industry cloud strategy for healthcare with the acquisition of Nuance
#
# April 12, 2021 | Microsoft News Center
#
# Share on Facebook (opens new window)
# '
#
# - 'on' found in document 1 in sentence: 'Request a Sample Copy of the Research Report:
# https://www.fortunebusinessinsights.com/enquiry/request-sample-pdf/artificial-intelligence-market-100114
#
# Microsoft accelerates industry cloud strategy for healthcare with the acquisition of Nuance
#
# April 12, 2021 | Microsoft News Center
#
# Share on Facebook (opens new window)
# '
#
# - 'Facebook' found in document 1 in sentence: 'Request a Sample Copy of the Research Report:
# https://www.fortunebusinessinsights.com/enquiry/request-sample-pdf/artificial-intelligence-market-100114
#
# Microsoft accelerates industry cloud strategy for healthcare with the acquisition of Nuance
#
# April 12, 2021 | Microsoft News Center
#
# Share on Facebook (opens new window)
# '
#
# - 'Microsoft' found in document 1 in sentence: 'Share on LinkedIn (opens new window)
#
#     Share on Twitter (opens new window)
#
# Acquisition will combine solutions and expertise to deliver new cloud and AI capabilities across healthcare and other industries
#
# Microsoft and Nuance logos
#
# REDMOND, Wash., and BURLINGTON, Mass. – April 12, 2021 – Microsoft Corp (Nasdaq: MSFT) and Nuance Communications, Inc. (Nasdaq: NUAN) today announced they have entered into a definitive agreement under which Microsoft will acquire Nuance for $56.00 per share, implying a 23% premium to the closing price of Nuance on Friday, April 9, in an all-cash transaction valued at $19.7 billion, inclusive of Nuance’s net debt.'
#
# - 'Microsoft' found in document 1 in sentence: 'Share on LinkedIn (opens new window)
#
#     Share on Twitter (opens new window)
#
# Acquisition will combine solutions and expertise to deliver new cloud and AI capabilities across healthcare and other industries
#
# Microsoft and Nuance logos
#
# REDMOND, Wash., and BURLINGTON, Mass. – April 12, 2021 – Microsoft Corp (Nasdaq: MSFT) and Nuance Communications, Inc. (Nasdaq: NUAN) today announced they have entered into a definitive agreement under which Microsoft will acquire Nuance for $56.00 per share, implying a 23% premium to the closing price of Nuance on Friday, April 9, in an all-cash transaction valued at $19.7 billion, inclusive of Nuance’s net debt.'
#
# - 'Corp' found in document 1 in sentence: 'Share on LinkedIn (opens new window)
#
#     Share on Twitter (opens new window)
#
# Acquisition will combine solutions and expertise to deliver new cloud and AI capabilities across healthcare and other industries
#
# Microsoft and Nuance logos
#
# REDMOND, Wash., and BURLINGTON, Mass. – April 12, 2021 – Microsoft Corp (Nasdaq: MSFT) and Nuance Communications, Inc. (Nasdaq: NUAN) today announced they have entered into a definitive agreement under which Microsoft will acquire Nuance for $56.00 per share, implying a 23% premium to the closing price of Nuance on Friday, April 9, in an all-cash transaction valued at $19.7 billion, inclusive of Nuance’s net debt.'
#
# - 'Nuance' found in document 1 in sentence: 'Share on LinkedIn (opens new window)
#
#     Share on Twitter (opens new window)
#
# Acquisition will combine solutions and expertise to deliver new cloud and AI capabilities across healthcare and other industries
#
# Microsoft and Nuance logos
#
# REDMOND, Wash., and BURLINGTON, Mass. – April 12, 2021 – Microsoft Corp (Nasdaq: MSFT) and Nuance Communications, Inc. (Nasdaq: NUAN) today announced they have entered into a definitive agreement under which Microsoft will acquire Nuance for $56.00 per share, implying a 23% premium to the closing price of Nuance on Friday, April 9, in an all-cash transaction valued at $19.7 billion, inclusive of Nuance’s net debt.'
#
# - 'Communications' found in document 1 in sentence: 'Share on LinkedIn (opens new window)
#
#     Share on Twitter (opens new window)
#
# Acquisition will combine solutions and expertise to deliver new cloud and AI capabilities across healthcare and other industries
#
# Microsoft and Nuance logos
#
# REDMOND, Wash., and BURLINGTON, Mass. – April 12, 2021 – Microsoft Corp (Nasdaq: MSFT) and Nuance Communications, Inc. (Nasdaq: NUAN) today announced they have entered into a definitive agreement under which Microsoft will acquire Nuance for $56.00 per share, implying a 23% premium to the closing price of Nuance on Friday, April 9, in an all-cash transaction valued at $19.7 billion, inclusive of Nuance’s net debt.'
#
# - ',' found in document 1 in sentence: 'Share on LinkedIn (opens new window)
#
#     Share on Twitter (opens new window)
#
# Acquisition will combine solutions and expertise to deliver new cloud and AI capabilities across healthcare and other industries
#
# Microsoft and Nuance logos
#
# REDMOND, Wash., and BURLINGTON, Mass. – April 12, 2021 – Microsoft Corp (Nasdaq: MSFT) and Nuance Communications, Inc. (Nasdaq: NUAN) today announced they have entered into a definitive agreement under which Microsoft will acquire Nuance for $56.00 per share, implying a 23% premium to the closing price of Nuance on Friday, April 9, in an all-cash transaction valued at $19.7 billion, inclusive of Nuance’s net debt.'
#
# - 'Inc.' found in document 1 in sentence: 'Share on LinkedIn (opens new window)
#
#     Share on Twitter (opens new window)
#
# Acquisition will combine solutions and expertise to deliver new cloud and AI capabilities across healthcare and other industries
#
# Microsoft and Nuance logos
#
# REDMOND, Wash., and BURLINGTON, Mass. – April 12, 2021 – Microsoft Corp (Nasdaq: MSFT) and Nuance Communications, Inc. (Nasdaq: NUAN) today announced they have entered into a definitive agreement under which Microsoft will acquire Nuance for $56.00 per share, implying a 23% premium to the closing price of Nuance on Friday, April 9, in an all-cash transaction valued at $19.7 billion, inclusive of Nuance’s net debt.'
#
# - 'Microsoft' found in document 1 in sentence: 'Share on LinkedIn (opens new window)
#
#     Share on Twitter (opens new window)
#
# Acquisition will combine solutions and expertise to deliver new cloud and AI capabilities across healthcare and other industries
#
# Microsoft and Nuance logos
#
# REDMOND, Wash., and BURLINGTON, Mass. – April 12, 2021 – Microsoft Corp (Nasdaq: MSFT) and Nuance Communications, Inc. (Nasdaq: NUAN) today announced they have entered into a definitive agreement under which Microsoft will acquire Nuance for $56.00 per share, implying a 23% premium to the closing price of Nuance on Friday, April 9, in an all-cash transaction valued at $19.7 billion, inclusive of Nuance’s net debt.'
#
# - 'Nuance' found in document 1 in sentence: 'Share on LinkedIn (opens new window)
#
#     Share on Twitter (opens new window)
#
# Acquisition will combine solutions and expertise to deliver new cloud and AI capabilities across healthcare and other industries
#
# Microsoft and Nuance logos
#
# REDMOND, Wash., and BURLINGTON, Mass. – April 12, 2021 – Microsoft Corp (Nasdaq: MSFT) and Nuance Communications, Inc. (Nasdaq: NUAN) today announced they have entered into a definitive agreement under which Microsoft will acquire Nuance for $56.00 per share, implying a 23% premium to the closing price of Nuance on Friday, April 9, in an all-cash transaction valued at $19.7 billion, inclusive of Nuance’s net debt.'
#
# - 'AI' found in document 1 in sentence: 'Nuance is a trusted cloud and AI software leader representing decades of accumulated healthcare and enterprise AI experience.'
#
# - 'Cloud' found in document 1 in sentence: 'Mark Benjamin will remain CEO of Nuance, reporting to Scott Guthrie, executive vice president of Cloud & AI at Microsoft.'
#
# - '&' found in document 1 in sentence: 'Mark Benjamin will remain CEO of Nuance, reporting to Scott Guthrie, executive vice president of Cloud & AI at Microsoft.'
#
# - 'AI' found in document 1 in sentence: 'Mark Benjamin will remain CEO of Nuance, reporting to Scott Guthrie, executive vice president of Cloud & AI at Microsoft.'
#
# - 'Microsoft' found in document 1 in sentence: 'Mark Benjamin will remain CEO of Nuance, reporting to Scott Guthrie, executive vice president of Cloud & AI at Microsoft.'
#
# - 'Microsoft' found in document 1 in sentence: 'Microsoft has accelerated its efforts to provide industry-specific cloud offerings to support customers and partners as they respond to disruption and new opportunities.'
#
# - 'Healthcare' found in document 1 in sentence: 'These efforts include the Microsoft Cloud for Healthcare, introduced in 2020, which aims to address the comprehensive needs of the rapidly transforming and growing healthcare industry.'
#
# - 'Microsoft' found in document 1 in sentence: 'Today’s acquisition announcement represents the latest step in Microsoft’s industry-specific cloud strategy.
#
# '
#
# - 'Dragon' found in document 1 in sentence: 'Nuance’s products include the Dragon Ambient eXperience, Dragon Medical One and PowerScribe One for radiology reporting, all leading clinical speech recognition SaaS offerings built on Microsoft Azure.'
#
# - 'Medical' found in document 1 in sentence: 'Nuance’s products include the Dragon Ambient eXperience, Dragon Medical One and PowerScribe One for radiology reporting, all leading clinical speech recognition SaaS offerings built on Microsoft Azure.'
#
# - 'One' found in document 1 in sentence: 'Nuance’s products include the Dragon Ambient eXperience, Dragon Medical One and PowerScribe One for radiology reporting, all leading clinical speech recognition SaaS offerings built on Microsoft Azure.'
#
# - 'PowerScribe' found in document 1 in sentence: 'Nuance’s products include the Dragon Ambient eXperience, Dragon Medical One and PowerScribe One for radiology reporting, all leading clinical speech recognition SaaS offerings built on Microsoft Azure.'
#
# - 'Microsoft' found in document 1 in sentence: 'Nuance’s products include the Dragon Ambient eXperience, Dragon Medical One and PowerScribe One for radiology reporting, all leading clinical speech recognition SaaS offerings built on Microsoft Azure.'
#
# - 'Azure' found in document 1 in sentence: 'Nuance’s products include the Dragon Ambient eXperience, Dragon Medical One and PowerScribe One for radiology reporting, all leading clinical speech recognition SaaS offerings built on Microsoft Azure.'
#
# - 'Electronic' found in document 1 in sentence: 'Nuance’s solutions work seamlessly with core healthcare systems, including longstanding relationships with Electronic Health Records (EHRs), to alleviate the burden of clinical documentation and empower providers to deliver better patient experiences.'
#
# - 'Health' found in document 1 in sentence: 'Nuance’s solutions work seamlessly with core healthcare systems, including longstanding relationships with Electronic Health Records (EHRs), to alleviate the burden of clinical documentation and empower providers to deliver better patient experiences.'
#
# - 'Records' found in document 1 in sentence: 'Nuance’s solutions work seamlessly with core healthcare systems, including longstanding relationships with Electronic Health Records (EHRs), to alleviate the burden of clinical documentation and empower providers to deliver better patient experiences.'
#
# - 'Healthcare' found in document 1 in sentence: 'Nuance’s Healthcare Cloud revenue experienced 37% year-over-year growth in Nuance’s fiscal year 2020 (ended September 2020).
#
# '
#
# - 'Cloud' found in document 1 in sentence: 'Nuance’s Healthcare Cloud revenue experienced 37% year-over-year growth in Nuance’s fiscal year 2020 (ended September 2020).
#
# '
#
# - 'Microsoft' found in document 1 in sentence: 'Microsoft’s acquisition of Nuance builds upon the successful existing partnership between the companies that was announced in 2019.'
#
# - 'Healthcare' found in document 1 in sentence: 'By augmenting the Microsoft Cloud for Healthcare with Nuance’s solutions, as well as the benefit of Nuance’s expertise and relationships with EHR systems providers, Microsoft will be better able to empower healthcare providers through the power of ambient clinical intelligence and other Microsoft cloud services.'
#
# - 'Nuance' found in document 1 in sentence: 'By augmenting the Microsoft Cloud for Healthcare with Nuance’s solutions, as well as the benefit of Nuance’s expertise and relationships with EHR systems providers, Microsoft will be better able to empower healthcare providers through the power of ambient clinical intelligence and other Microsoft cloud services.'
#
# - 'Microsoft' found in document 1 in sentence: 'By augmenting the Microsoft Cloud for Healthcare with Nuance’s solutions, as well as the benefit of Nuance’s expertise and relationships with EHR systems providers, Microsoft will be better able to empower healthcare providers through the power of ambient clinical intelligence and other Microsoft cloud services.'
#
# - 'Microsoft' found in document 1 in sentence: 'By augmenting the Microsoft Cloud for Healthcare with Nuance’s solutions, as well as the benefit of Nuance’s expertise and relationships with EHR systems providers, Microsoft will be better able to empower healthcare providers through the power of ambient clinical intelligence and other Microsoft cloud services.'
#
# - 'Microsoft' found in document 1 in sentence: 'The acquisition will double Microsoft’s total addressable market (TAM) in the healthcare provider space, bringing the company’s TAM in healthcare to nearly $500 billion.'
#
# - 'TAM' found in document 1 in sentence: 'The acquisition will double Microsoft’s total addressable market (TAM) in the healthcare provider space, bringing the company’s TAM in healthcare to nearly $500 billion.'
#
# - 'TAM' found in document 1 in sentence: 'The acquisition will double Microsoft’s total addressable market (TAM) in the healthcare provider space, bringing the company’s TAM in healthcare to nearly $500 billion.'
#
# - 'Microsoft' found in document 1 in sentence: 'Nuance and Microsoft will deepen their existing commitments to the extended partner ecosystem, as well as the highest standards of data privacy, security and compliance.
#
# '
#
# - 'AI' found in document 1 in sentence: '“Nuance provides the AI layer at the healthcare point of delivery and is a pioneer in the real-world application of enterprise AI,” said Satya Nadella, CEO, Microsoft.'
#
# - 'Microsoft' found in document 1 in sentence: '“Nuance provides the AI layer at the healthcare point of delivery and is a pioneer in the real-world application of enterprise AI,” said Satya Nadella, CEO, Microsoft.'
#
# - 'healthcare' found in document 1 in sentence: '“AI is technology’s most important priority, and healthcare is its most urgent application.'
#
# - 'Microsoft' found in document 1 in sentence: 'Together, with our partner ecosystem, we will put advanced AI solutions into the hands of professionals everywhere to drive better decision-making and create more meaningful connections, as we accelerate growth of Microsoft Cloud for Healthcare and Nuance.”
#
# Beyond healthcare, Nuance provides AI expertise and customer engagement solutions across Interactive Voice Response (IVR), virtual assistants, and digital and biometric solutions to companies around the world across all industries.'
#
# - 'Cloud' found in document 1 in sentence: 'Together, with our partner ecosystem, we will put advanced AI solutions into the hands of professionals everywhere to drive better decision-making and create more meaningful connections, as we accelerate growth of Microsoft Cloud for Healthcare and Nuance.”
#
# Beyond healthcare, Nuance provides AI expertise and customer engagement solutions across Interactive Voice Response (IVR), virtual assistants, and digital and biometric solutions to companies around the world across all industries.'
#
# - 'for' found in document 1 in sentence: 'Together, with our partner ecosystem, we will put advanced AI solutions into the hands of professionals everywhere to drive better decision-making and create more meaningful connections, as we accelerate growth of Microsoft Cloud for Healthcare and Nuance.”
#
# Beyond healthcare, Nuance provides AI expertise and customer engagement solutions across Interactive Voice Response (IVR), virtual assistants, and digital and biometric solutions to companies around the world across all industries.'
#
# - 'Healthcare' found in document 1 in sentence: 'Together, with our partner ecosystem, we will put advanced AI solutions into the hands of professionals everywhere to drive better decision-making and create more meaningful connections, as we accelerate growth of Microsoft Cloud for Healthcare and Nuance.”
#
# Beyond healthcare, Nuance provides AI expertise and customer engagement solutions across Interactive Voice Response (IVR), virtual assistants, and digital and biometric solutions to companies around the world across all industries.'
#
# - 'AI' found in document 1 in sentence: 'Together, with our partner ecosystem, we will put advanced AI solutions into the hands of professionals everywhere to drive better decision-making and create more meaningful connections, as we accelerate growth of Microsoft Cloud for Healthcare and Nuance.”
#
# Beyond healthcare, Nuance provides AI expertise and customer engagement solutions across Interactive Voice Response (IVR), virtual assistants, and digital and biometric solutions to companies around the world across all industries.'
#
# - 'Interactive' found in document 1 in sentence: 'Together, with our partner ecosystem, we will put advanced AI solutions into the hands of professionals everywhere to drive better decision-making and create more meaningful connections, as we accelerate growth of Microsoft Cloud for Healthcare and Nuance.”
#
# Beyond healthcare, Nuance provides AI expertise and customer engagement solutions across Interactive Voice Response (IVR), virtual assistants, and digital and biometric solutions to companies around the world across all industries.'
#
# - 'Voice' found in document 1 in sentence: 'Together, with our partner ecosystem, we will put advanced AI solutions into the hands of professionals everywhere to drive better decision-making and create more meaningful connections, as we accelerate growth of Microsoft Cloud for Healthcare and Nuance.”
#
# Beyond healthcare, Nuance provides AI expertise and customer engagement solutions across Interactive Voice Response (IVR), virtual assistants, and digital and biometric solutions to companies around the world across all industries.'
#
# - 'Response' found in document 1 in sentence: 'Together, with our partner ecosystem, we will put advanced AI solutions into the hands of professionals everywhere to drive better decision-making and create more meaningful connections, as we accelerate growth of Microsoft Cloud for Healthcare and Nuance.”
#
# Beyond healthcare, Nuance provides AI expertise and customer engagement solutions across Interactive Voice Response (IVR), virtual assistants, and digital and biometric solutions to companies around the world across all industries.'
#
# - 'Microsoft' found in document 1 in sentence: 'This expertise will come together with the breadth and depth of Microsoft’s cloud, including Azure, Teams, and Dynamics 365, to deliver next-generation customer engagement and security solutions.
#
# '
#
# - 'Azure' found in document 1 in sentence: 'This expertise will come together with the breadth and depth of Microsoft’s cloud, including Azure, Teams, and Dynamics 365, to deliver next-generation customer engagement and security solutions.
#
# '
#
# - 'Dynamics' found in document 1 in sentence: 'This expertise will come together with the breadth and depth of Microsoft’s cloud, including Azure, Teams, and Dynamics 365, to deliver next-generation customer engagement and security solutions.
#
# '
#
# - '365' found in document 1 in sentence: 'This expertise will come together with the breadth and depth of Microsoft’s cloud, including Azure, Teams, and Dynamics 365, to deliver next-generation customer engagement and security solutions.
#
# '
#
# - 'Nuance' found in document 1 in sentence: '“Over the past three years, Nuance has streamlined its portfolio to focus on the healthcare and enterprise AI segments, where there has been accelerated demand for advanced conversational AI and ambient solutions,” said Mark Benjamin, CEO, Nuance.'
#
# - 'Microsoft' found in document 1 in sentence: 'The path forward is clearly with Microsoft —  who brings intelligent cloud-based services at scale and who shares our passion for the ways technology can make a difference.'
#
# - 'the' found in document 1 in sentence: 'The transaction has been unanimously approved by the Boards of Directors of both Nuance and Microsoft.'
#
# - 'Boards' found in document 1 in sentence: 'The transaction has been unanimously approved by the Boards of Directors of both Nuance and Microsoft.'
#
# - 'of' found in document 1 in sentence: 'The transaction has been unanimously approved by the Boards of Directors of both Nuance and Microsoft.'
#
# - 'Directors' found in document 1 in sentence: 'The transaction has been unanimously approved by the Boards of Directors of both Nuance and Microsoft.'
#
# - 'Microsoft' found in document 1 in sentence: 'The transaction has been unanimously approved by the Boards of Directors of both Nuance and Microsoft.'
#
# - 'Nuance' found in document 1 in sentence: 'The deal is intended to close by the end of this calendar year and is subject to approval by Nuance’s shareholders, the satisfaction of certain regulatory approvals, and other customary closing conditions.
#
# '
#
# - 'Microsoft' found in document 1 in sentence: 'Upon closing, Microsoft expects Nuance’s financials to be reported as part of Microsoft’s Intelligent Cloud segment.'
#
# - 'Nuance' found in document 1 in sentence: 'Upon closing, Microsoft expects Nuance’s financials to be reported as part of Microsoft’s Intelligent Cloud segment.'
#
# - 'Microsoft' found in document 1 in sentence: 'Upon closing, Microsoft expects Nuance’s financials to be reported as part of Microsoft’s Intelligent Cloud segment.'
#
# - 'Microsoft' found in document 1 in sentence: 'Microsoft expects the acquisition to be minimally dilutive (less than 1 percent) in fiscal year 2022 and to be accretive in fiscal year 2023 to non-GAAP earnings per share, based on the expected close timeframe.'
#
# - 'Microsoft' found in document 1 in sentence: 'Nadella, Benjamin, Guthrie and Microsoft Chief Financial Officer Amy Hood will host a webcast for investors and media on April 12, 2021, at 8 a.m.'
#
# - 'Goldman' found in document 1 in sentence: 'Goldman Sachs & Co. LLC is acting as exclusive financial advisor to Microsoft, while Simpson Thacher & Bartlett LLP is acting as its legal advisor.'
#
# - 'Sachs' found in document 1 in sentence: 'Goldman Sachs & Co. LLC is acting as exclusive financial advisor to Microsoft, while Simpson Thacher & Bartlett LLP is acting as its legal advisor.'
#
# - '&' found in document 1 in sentence: 'Goldman Sachs & Co. LLC is acting as exclusive financial advisor to Microsoft, while Simpson Thacher & Bartlett LLP is acting as its legal advisor.'
#
# - 'Co.' found in document 1 in sentence: 'Goldman Sachs & Co. LLC is acting as exclusive financial advisor to Microsoft, while Simpson Thacher & Bartlett LLP is acting as its legal advisor.'
#
# - 'LLC' found in document 1 in sentence: 'Goldman Sachs & Co. LLC is acting as exclusive financial advisor to Microsoft, while Simpson Thacher & Bartlett LLP is acting as its legal advisor.'
#
# - 'Microsoft' found in document 1 in sentence: 'Goldman Sachs & Co. LLC is acting as exclusive financial advisor to Microsoft, while Simpson Thacher & Bartlett LLP is acting as its legal advisor.'
#
# - 'Simpson' found in document 1 in sentence: 'Goldman Sachs & Co. LLC is acting as exclusive financial advisor to Microsoft, while Simpson Thacher & Bartlett LLP is acting as its legal advisor.'
#
# - 'Thacher' found in document 1 in sentence: 'Goldman Sachs & Co. LLC is acting as exclusive financial advisor to Microsoft, while Simpson Thacher & Bartlett LLP is acting as its legal advisor.'
#
# - '&' found in document 1 in sentence: 'Goldman Sachs & Co. LLC is acting as exclusive financial advisor to Microsoft, while Simpson Thacher & Bartlett LLP is acting as its legal advisor.'
#
# - 'Bartlett' found in document 1 in sentence: 'Goldman Sachs & Co. LLC is acting as exclusive financial advisor to Microsoft, while Simpson Thacher & Bartlett LLP is acting as its legal advisor.'
#
# - 'LLP' found in document 1 in sentence: 'Goldman Sachs & Co. LLC is acting as exclusive financial advisor to Microsoft, while Simpson Thacher & Bartlett LLP is acting as its legal advisor.'
#
# - 'Paul' found in document 1 in sentence: 'Evercore is acting as exclusive financial advisor to Nuance, while Paul, Weiss, Rifkind, Wharton & Garrison LLP is acting as its legal advisor.
#
# '
#
# - ',' found in document 1 in sentence: 'Evercore is acting as exclusive financial advisor to Nuance, while Paul, Weiss, Rifkind, Wharton & Garrison LLP is acting as its legal advisor.
#
# '
#
# - 'Weiss' found in document 1 in sentence: 'Evercore is acting as exclusive financial advisor to Nuance, while Paul, Weiss, Rifkind, Wharton & Garrison LLP is acting as its legal advisor.
#
# '
#
# - ',' found in document 1 in sentence: 'Evercore is acting as exclusive financial advisor to Nuance, while Paul, Weiss, Rifkind, Wharton & Garrison LLP is acting as its legal advisor.
#
# '
#
# - 'Rifkind' found in document 1 in sentence: 'Evercore is acting as exclusive financial advisor to Nuance, while Paul, Weiss, Rifkind, Wharton & Garrison LLP is acting as its legal advisor.
#
# '
#
# - ',' found in document 1 in sentence: 'Evercore is acting as exclusive financial advisor to Nuance, while Paul, Weiss, Rifkind, Wharton & Garrison LLP is acting as its legal advisor.
#
# '
#
# - 'Wharton' found in document 1 in sentence: 'Evercore is acting as exclusive financial advisor to Nuance, while Paul, Weiss, Rifkind, Wharton & Garrison LLP is acting as its legal advisor.
#
# '
#
# - '&' found in document 1 in sentence: 'Evercore is acting as exclusive financial advisor to Nuance, while Paul, Weiss, Rifkind, Wharton & Garrison LLP is acting as its legal advisor.
#
# '
#
# - 'Garrison' found in document 1 in sentence: 'Evercore is acting as exclusive financial advisor to Nuance, while Paul, Weiss, Rifkind, Wharton & Garrison LLP is acting as its legal advisor.
#
# '
#
# - 'LLP' found in document 1 in sentence: 'Evercore is acting as exclusive financial advisor to Nuance, while Paul, Weiss, Rifkind, Wharton & Garrison LLP is acting as its legal advisor.
#
# '
#
# - 'Microsoft' found in document 1 in sentence: 'About Microsoft
# Microsoft (Nasdaq “MSFT” @microsoft) enables digital transformation for the era of an intelligent cloud and an intelligent edge.'
#
# - '
# ' found in document 1 in sentence: 'About Microsoft
# Microsoft (Nasdaq “MSFT” @microsoft) enables digital transformation for the era of an intelligent cloud and an intelligent edge.'
#
# - 'Microsoft' found in document 1 in sentence: 'About Microsoft
# Microsoft (Nasdaq “MSFT” @microsoft) enables digital transformation for the era of an intelligent cloud and an intelligent edge.'
#
# - 'About' found in document 1 in sentence: 'About Nuance Communications, Inc.
# Nuance Communications (NASDAQ: NUAN) is a technology pioneer with market leadership in conversational AI and ambient intelligence.'
#
# - 'Nuance' found in document 1 in sentence: 'About Nuance Communications, Inc.
# Nuance Communications (NASDAQ: NUAN) is a technology pioneer with market leadership in conversational AI and ambient intelligence.'
#
# - 'Communications' found in document 1 in sentence: 'About Nuance Communications, Inc.
# Nuance Communications (NASDAQ: NUAN) is a technology pioneer with market leadership in conversational AI and ambient intelligence.'
#
# - ',' found in document 1 in sentence: 'About Nuance Communications, Inc.
# Nuance Communications (NASDAQ: NUAN) is a technology pioneer with market leadership in conversational AI and ambient intelligence.'
#
# - 'Inc.' found in document 1 in sentence: 'About Nuance Communications, Inc.
# Nuance Communications (NASDAQ: NUAN) is a technology pioneer with market leadership in conversational AI and ambient intelligence.'
#
# - '
# ' found in document 1 in sentence: 'About Nuance Communications, Inc.
# Nuance Communications (NASDAQ: NUAN) is a technology pioneer with market leadership in conversational AI and ambient intelligence.'
#
# - 'Nuance' found in document 1 in sentence: 'About Nuance Communications, Inc.
# Nuance Communications (NASDAQ: NUAN) is a technology pioneer with market leadership in conversational AI and ambient intelligence.'
#
# - 'Communications' found in document 1 in sentence: 'About Nuance Communications, Inc.
# Nuance Communications (NASDAQ: NUAN) is a technology pioneer with market leadership in conversational AI and ambient intelligence.'
#
# - 'Microsoft' found in document 1 in sentence: 'For more information, press only:
#
# Microsoft Media Relations, WE Communications, (425) 638-7777, rrt@we-worldwide.com
#
# Note to editors: For more information, news and perspectives from Microsoft, please visit the Microsoft News Center at http://news.microsoft.com.'
#
# - 'Media' found in document 1 in sentence: 'For more information, press only:
#
# Microsoft Media Relations, WE Communications, (425) 638-7777, rrt@we-worldwide.com
#
# Note to editors: For more information, news and perspectives from Microsoft, please visit the Microsoft News Center at http://news.microsoft.com.'
#
# - 'Relations' found in document 1 in sentence: 'For more information, press only:
#
# Microsoft Media Relations, WE Communications, (425) 638-7777, rrt@we-worldwide.com
#
# Note to editors: For more information, news and perspectives from Microsoft, please visit the Microsoft News Center at http://news.microsoft.com.'
#
# - 'WE' found in document 1 in sentence: 'For more information, press only:
#
# Microsoft Media Relations, WE Communications, (425) 638-7777, rrt@we-worldwide.com
#
# Note to editors: For more information, news and perspectives from Microsoft, please visit the Microsoft News Center at http://news.microsoft.com.'
#
# - 'Communications' found in document 1 in sentence: 'For more information, press only:
#
# Microsoft Media Relations, WE Communications, (425) 638-7777, rrt@we-worldwide.com
#
# Note to editors: For more information, news and perspectives from Microsoft, please visit the Microsoft News Center at http://news.microsoft.com.'
#
# - 'Microsoft' found in document 1 in sentence: 'For more information, press only:
#
# Microsoft Media Relations, WE Communications, (425) 638-7777, rrt@we-worldwide.com
#
# Note to editors: For more information, news and perspectives from Microsoft, please visit the Microsoft News Center at http://news.microsoft.com.'
#
# - 'the' found in document 1 in sentence: 'For more information, press only:
#
# Microsoft Media Relations, WE Communications, (425) 638-7777, rrt@we-worldwide.com
#
# Note to editors: For more information, news and perspectives from Microsoft, please visit the Microsoft News Center at http://news.microsoft.com.'
#
# - 'Microsoft' found in document 1 in sentence: 'For more information, press only:
#
# Microsoft Media Relations, WE Communications, (425) 638-7777, rrt@we-worldwide.com
#
# Note to editors: For more information, news and perspectives from Microsoft, please visit the Microsoft News Center at http://news.microsoft.com.'
#
# - 'News' found in document 1 in sentence: 'For more information, press only:
#
# Microsoft Media Relations, WE Communications, (425) 638-7777, rrt@we-worldwide.com
#
# Note to editors: For more information, news and perspectives from Microsoft, please visit the Microsoft News Center at http://news.microsoft.com.'
#
# - 'Center' found in document 1 in sentence: 'For more information, press only:
#
# Microsoft Media Relations, WE Communications, (425) 638-7777, rrt@we-worldwide.com
#
# Note to editors: For more information, news and perspectives from Microsoft, please visit the Microsoft News Center at http://news.microsoft.com.'
#
# - 'Microsoft' found in document 1 in sentence: 'For additional assistance, journalists and analysts may contact Microsoft’s Rapid Response Team or other appropriate contacts listed at https://news.microsoft.com/microsoft-public-relations-contacts.
#
# '
#
# - 'Rapid' found in document 1 in sentence: 'For additional assistance, journalists and analysts may contact Microsoft’s Rapid Response Team or other appropriate contacts listed at https://news.microsoft.com/microsoft-public-relations-contacts.
#
# '
#
# - 'Response' found in document 1 in sentence: 'For additional assistance, journalists and analysts may contact Microsoft’s Rapid Response Team or other appropriate contacts listed at https://news.microsoft.com/microsoft-public-relations-contacts.
#
# '
#
# - 'Team' found in document 1 in sentence: 'For additional assistance, journalists and analysts may contact Microsoft’s Rapid Response Team or other appropriate contacts listed at https://news.microsoft.com/microsoft-public-relations-contacts.
#
# '
#
# - 'Nuance' found in document 1 in sentence: 'Trademark reference: Nuance and the Nuance logo are registered trademarks or trademarks of Nuance Communications, Inc. or its affiliates in the United States and/or other countries.'
#
# - 'Communications' found in document 1 in sentence: 'Trademark reference: Nuance and the Nuance logo are registered trademarks or trademarks of Nuance Communications, Inc. or its affiliates in the United States and/or other countries.'
#
# - ',' found in document 1 in sentence: 'Trademark reference: Nuance and the Nuance logo are registered trademarks or trademarks of Nuance Communications, Inc. or its affiliates in the United States and/or other countries.'
#
# - 'Inc.' found in document 1 in sentence: 'Trademark reference: Nuance and the Nuance logo are registered trademarks or trademarks of Nuance Communications, Inc. or its affiliates in the United States and/or other countries.'
#
# - 'Grand' found in document 2 in sentence: 'And according to Grand View Research, Inc., it is projected to expand at a compound annual growth rate (CAGR) of 38.1% from 2022 to 2030.'
#
# - 'View' found in document 2 in sentence: 'And according to Grand View Research, Inc., it is projected to expand at a compound annual growth rate (CAGR) of 38.1% from 2022 to 2030.'
#
# - 'Research' found in document 2 in sentence: 'And according to Grand View Research, Inc., it is projected to expand at a compound annual growth rate (CAGR) of 38.1% from 2022 to 2030.'
#
# - ',' found in document 2 in sentence: 'And according to Grand View Research, Inc., it is projected to expand at a compound annual growth rate (CAGR) of 38.1% from 2022 to 2030.'
#
# - 'Inc.' found in document 2 in sentence: 'And according to Grand View Research, Inc., it is projected to expand at a compound annual growth rate (CAGR) of 38.1% from 2022 to 2030.'
#
# - 'AI' found in document 2 in sentence: 'Additionally, advancements in cloud computing technology, along with developments in deep learning algorithms, have increased the adoption rate of AI.
#
# Artificial intelligence growth can be attributed to its widespread application across diverse sectors, including healthcare, retail, and finance.'
#
# - 'AI' found in document 2 in sentence: 'These hurdles include high infrastructure costs associated with implementing AI systems and a lack of awareness about these technologies among businesses that could benefit from them.
#
# '
#
# - 'AI' found in document 2 in sentence: 'Based on application, AI has segmented into healthcare and life sciences; manufacturing and logistics; energy and utilities; banking, financial services, and insurance (BFSI); process manufacturing industries; retail and eCommerce; and agriculture and forestry sectors (agribusinesses).
#
# '
#
# - 'NVIDIA' found in document 2 in sentence: 'Additionally, there are developments in drug optimization through predictive analytics tools provided by leading players, such as NVIDIA Corporation (NVDA), Intel Corporation (INTC), Alphabet Inc. (GOOGL), and Amazon Web Services Inc. (AMZN).'
#
# - 'Corporation' found in document 2 in sentence: 'Additionally, there are developments in drug optimization through predictive analytics tools provided by leading players, such as NVIDIA Corporation (NVDA), Intel Corporation (INTC), Alphabet Inc. (GOOGL), and Amazon Web Services Inc. (AMZN).'
#
# - 'NVDA' found in document 2 in sentence: 'Additionally, there are developments in drug optimization through predictive analytics tools provided by leading players, such as NVIDIA Corporation (NVDA), Intel Corporation (INTC), Alphabet Inc. (GOOGL), and Amazon Web Services Inc. (AMZN).'
#
# - 'Intel' found in document 2 in sentence: 'Additionally, there are developments in drug optimization through predictive analytics tools provided by leading players, such as NVIDIA Corporation (NVDA), Intel Corporation (INTC), Alphabet Inc. (GOOGL), and Amazon Web Services Inc. (AMZN).'
#
# - 'Corporation' found in document 2 in sentence: 'Additionally, there are developments in drug optimization through predictive analytics tools provided by leading players, such as NVIDIA Corporation (NVDA), Intel Corporation (INTC), Alphabet Inc. (GOOGL), and Amazon Web Services Inc. (AMZN).'
#
# - 'Alphabet' found in document 2 in sentence: 'Additionally, there are developments in drug optimization through predictive analytics tools provided by leading players, such as NVIDIA Corporation (NVDA), Intel Corporation (INTC), Alphabet Inc. (GOOGL), and Amazon Web Services Inc. (AMZN).'
#
# - 'Inc.' found in document 2 in sentence: 'Additionally, there are developments in drug optimization through predictive analytics tools provided by leading players, such as NVIDIA Corporation (NVDA), Intel Corporation (INTC), Alphabet Inc. (GOOGL), and Amazon Web Services Inc. (AMZN).'
#
# - 'Amazon' found in document 2 in sentence: 'Additionally, there are developments in drug optimization through predictive analytics tools provided by leading players, such as NVIDIA Corporation (NVDA), Intel Corporation (INTC), Alphabet Inc. (GOOGL), and Amazon Web Services Inc. (AMZN).'
#
# - 'Web' found in document 2 in sentence: 'Additionally, there are developments in drug optimization through predictive analytics tools provided by leading players, such as NVIDIA Corporation (NVDA), Intel Corporation (INTC), Alphabet Inc. (GOOGL), and Amazon Web Services Inc. (AMZN).'
#
# - 'Services' found in document 2 in sentence: 'Additionally, there are developments in drug optimization through predictive analytics tools provided by leading players, such as NVIDIA Corporation (NVDA), Intel Corporation (INTC), Alphabet Inc. (GOOGL), and Amazon Web Services Inc. (AMZN).'
#
# - 'Inc.' found in document 2 in sentence: 'Additionally, there are developments in drug optimization through predictive analytics tools provided by leading players, such as NVIDIA Corporation (NVDA), Intel Corporation (INTC), Alphabet Inc. (GOOGL), and Amazon Web Services Inc. (AMZN).'
#
# - 'AMZN' found in document 2 in sentence: 'Additionally, there are developments in drug optimization through predictive analytics tools provided by leading players, such as NVIDIA Corporation (NVDA), Intel Corporation (INTC), Alphabet Inc. (GOOGL), and Amazon Web Services Inc. (AMZN).'
#
# - 'Artificial' found in document 2 in sentence: 'Artificial Intelligence Market by Component Analysis
#
# AI market analysis can be segmented into hardware, software, and service components.'
#
# - 'Intelligence' found in document 2 in sentence: 'Artificial Intelligence Market by Component Analysis
#
# AI market analysis can be segmented into hardware, software, and service components.'
#
# - 'Market' found in document 2 in sentence: 'Artificial Intelligence Market by Component Analysis
#
# AI market analysis can be segmented into hardware, software, and service components.'
#
# - 'by' found in document 2 in sentence: 'Artificial Intelligence Market by Component Analysis
#
# AI market analysis can be segmented into hardware, software, and service components.'
#
# - 'Component' found in document 2 in sentence: 'Artificial Intelligence Market by Component Analysis
#
# AI market analysis can be segmented into hardware, software, and service components.'
#
# - 'Analysis' found in document 2 in sentence: 'Artificial Intelligence Market by Component Analysis
#
# AI market analysis can be segmented into hardware, software, and service components.'
#
# - 'Artificial' found in document 2 in sentence: 'Artificial Intelligence Market by Technology
#
# There are many different types of artificial intelligence, so it can be difficult to understand the market without an overview of the technology.'
#
# - 'Intelligence' found in document 2 in sentence: 'Artificial Intelligence Market by Technology
#
# There are many different types of artificial intelligence, so it can be difficult to understand the market without an overview of the technology.'
#
# - 'Market' found in document 2 in sentence: 'Artificial Intelligence Market by Technology
#
# There are many different types of artificial intelligence, so it can be difficult to understand the market without an overview of the technology.'
#
# - 'by' found in document 2 in sentence: 'Artificial Intelligence Market by Technology
#
# There are many different types of artificial intelligence, so it can be difficult to understand the market without an overview of the technology.'
#
# - 'Technology' found in document 2 in sentence: 'Artificial Intelligence Market by Technology
#
# There are many different types of artificial intelligence, so it can be difficult to understand the market without an overview of the technology.'
#
# - 'AI' found in document 2 in sentence: 'The AI market is further segmented by technology.'
#
# - 'NLP' found in document 2 in sentence: 'Natural language processing (NLP), machine learning, context-aware computing, computer vision, and virtual agents are some major technologies used in the AI market.
#
# '
#
# - 'AI' found in document 2 in sentence: 'Natural language processing (NLP), machine learning, context-aware computing, computer vision, and virtual agents are some major technologies used in the AI market.
#
# '
#
# - 'NLP' found in document 2 in sentence: 'NLP enables a system to understand human language through various methods like speech recognition and natural language understanding.'
#
# - 'Artificial' found in document 2 in sentence: 'Artificial Intelligence Market by End-User Industry
#
# The AI market is segmented by end-user industry into retail, healthcare and life sciences, automotive and transportation, BFSI, consumer goods and retail, manufacturing, media and entertainment, agriculture and food, and energy and utilities.
#
# '
#
# - 'Intelligence' found in document 2 in sentence: 'Artificial Intelligence Market by End-User Industry
#
# The AI market is segmented by end-user industry into retail, healthcare and life sciences, automotive and transportation, BFSI, consumer goods and retail, manufacturing, media and entertainment, agriculture and food, and energy and utilities.
#
# '
#
# - 'Market' found in document 2 in sentence: 'Artificial Intelligence Market by End-User Industry
#
# The AI market is segmented by end-user industry into retail, healthcare and life sciences, automotive and transportation, BFSI, consumer goods and retail, manufacturing, media and entertainment, agriculture and food, and energy and utilities.
#
# '
#
# - 'AI' found in document 2 in sentence: 'Artificial Intelligence Market by End-User Industry
#
# The AI market is segmented by end-user industry into retail, healthcare and life sciences, automotive and transportation, BFSI, consumer goods and retail, manufacturing, media and entertainment, agriculture and food, and energy and utilities.
#
# '
#
# - 'AI' found in document 2 in sentence: 'The retail sector accounted for one of the largest shares of the AI market in 2020.'
#
# - 'PMFD' found in document 2 in sentence: 'For example, personalized treatment for diabetes (PMFD) uses knowledge about a person’s genetic composition to modify tactics for preventing, diagnosing, treating, or monitoring diabetes.
# '
#
# - 'AI' found in document 2 in sentence: 'COVID-19 Impact on Global Al Market
#
# As businesses and other organizations worldwide have been dealing with the consequences of the ongoing COVID-19 pandemic and plan for a post-pandemic future, one critical question arises: how much did COVID affect the AI market globally?
#
# '
#
# - 'Stanford' found in document 2 in sentence: '“AI is still in the early stages of a long secular growth trend,” says Erik Brynjolfsson, professor and senior fellow at Stanford Institute for Human-Centered AI (HAI) and director of the Stanford Digital Economy Lab.'
#
# - 'Institute' found in document 2 in sentence: '“AI is still in the early stages of a long secular growth trend,” says Erik Brynjolfsson, professor and senior fellow at Stanford Institute for Human-Centered AI (HAI) and director of the Stanford Digital Economy Lab.'
#
# - 'for' found in document 2 in sentence: '“AI is still in the early stages of a long secular growth trend,” says Erik Brynjolfsson, professor and senior fellow at Stanford Institute for Human-Centered AI (HAI) and director of the Stanford Digital Economy Lab.'
#
# - 'Human' found in document 2 in sentence: '“AI is still in the early stages of a long secular growth trend,” says Erik Brynjolfsson, professor and senior fellow at Stanford Institute for Human-Centered AI (HAI) and director of the Stanford Digital Economy Lab.'
#
# - '-' found in document 2 in sentence: '“AI is still in the early stages of a long secular growth trend,” says Erik Brynjolfsson, professor and senior fellow at Stanford Institute for Human-Centered AI (HAI) and director of the Stanford Digital Economy Lab.'
#
# - 'Centered' found in document 2 in sentence: '“AI is still in the early stages of a long secular growth trend,” says Erik Brynjolfsson, professor and senior fellow at Stanford Institute for Human-Centered AI (HAI) and director of the Stanford Digital Economy Lab.'
#
# - 'the' found in document 2 in sentence: '“AI is still in the early stages of a long secular growth trend,” says Erik Brynjolfsson, professor and senior fellow at Stanford Institute for Human-Centered AI (HAI) and director of the Stanford Digital Economy Lab.'
#
# - 'Stanford' found in document 2 in sentence: '“AI is still in the early stages of a long secular growth trend,” says Erik Brynjolfsson, professor and senior fellow at Stanford Institute for Human-Centered AI (HAI) and director of the Stanford Digital Economy Lab.'
#
# - 'Digital' found in document 2 in sentence: '“AI is still in the early stages of a long secular growth trend,” says Erik Brynjolfsson, professor and senior fellow at Stanford Institute for Human-Centered AI (HAI) and director of the Stanford Digital Economy Lab.'
#
# - 'Economy' found in document 2 in sentence: '“AI is still in the early stages of a long secular growth trend,” says Erik Brynjolfsson, professor and senior fellow at Stanford Institute for Human-Centered AI (HAI) and director of the Stanford Digital Economy Lab.'
#
# - 'Lab' found in document 2 in sentence: '“AI is still in the early stages of a long secular growth trend,” says Erik Brynjolfsson, professor and senior fellow at Stanford Institute for Human-Centered AI (HAI) and director of the Stanford Digital Economy Lab.'
#
# - 'AI' found in document 2 in sentence: 'According to an annual study on AI and its impact and progress developed by Stanford HAI, hiring, investment, and adoption of AI grew in 2020, reflecting long-term business trends that would likely outlive the pandemic’s effects.
#
# '
#
# - 'Stanford' found in document 2 in sentence: 'According to an annual study on AI and its impact and progress developed by Stanford HAI, hiring, investment, and adoption of AI grew in 2020, reflecting long-term business trends that would likely outlive the pandemic’s effects.
#
# '
#
# - 'AI' found in document 2 in sentence: 'According to an annual study on AI and its impact and progress developed by Stanford HAI, hiring, investment, and adoption of AI grew in 2020, reflecting long-term business trends that would likely outlive the pandemic’s effects.
#
# '
#
# - 'AI' found in document 2 in sentence: 'As a result, the AI industry saw substantial hiring growth during COVID-19.'
#
# - 'AI' found in document 2 in sentence: 'Manufacturing and retail are expected to grow in hiring AI-related jobs, thus catching up with healthcare, finance, and other service industries that have been strong early adopters of AI.
# Growing Investments in Artificial Intelligence Systems
#
# '
#
# - 'Growing' found in document 2 in sentence: 'Manufacturing and retail are expected to grow in hiring AI-related jobs, thus catching up with healthcare, finance, and other service industries that have been strong early adopters of AI.
# Growing Investments in Artificial Intelligence Systems
#
# '
#
# - 'Investments' found in document 2 in sentence: 'Manufacturing and retail are expected to grow in hiring AI-related jobs, thus catching up with healthcare, finance, and other service industries that have been strong early adopters of AI.
# Growing Investments in Artificial Intelligence Systems
#
# '
#
# - 'in' found in document 2 in sentence: 'Manufacturing and retail are expected to grow in hiring AI-related jobs, thus catching up with healthcare, finance, and other service industries that have been strong early adopters of AI.
# Growing Investments in Artificial Intelligence Systems
#
# '
#
# - 'Artificial' found in document 2 in sentence: 'Manufacturing and retail are expected to grow in hiring AI-related jobs, thus catching up with healthcare, finance, and other service industries that have been strong early adopters of AI.
# Growing Investments in Artificial Intelligence Systems
#
# '
#
# - 'Intelligence' found in document 2 in sentence: 'Manufacturing and retail are expected to grow in hiring AI-related jobs, thus catching up with healthcare, finance, and other service industries that have been strong early adopters of AI.
# Growing Investments in Artificial Intelligence Systems
#
# '
#
# - 'Systems' found in document 2 in sentence: 'Manufacturing and retail are expected to grow in hiring AI-related jobs, thus catching up with healthcare, finance, and other service industries that have been strong early adopters of AI.
# Growing Investments in Artificial Intelligence Systems
#
# '
#
# - 'Tortoise' found in document 2 in sentence: 'According to Tortoise Intelligence, global investment in AI firms has surged by 115% since 2020, the biggest year-over-year increase in AI investment in at least two decades.
#
# '
#
# - 'Intelligence' found in document 2 in sentence: 'According to Tortoise Intelligence, global investment in AI firms has surged by 115% since 2020, the biggest year-over-year increase in AI investment in at least two decades.
#
# '
#
# - 'The' found in document 2 in sentence: 'The European Union (EU) has also created an initiative called Horizon 2020 that aims to invest €1 billion per year into research projects related to future technologies, such as artificial intelligence, robotics, nanotechnology, and advanced manufacturing processes.
# '
#
# - 'European' found in document 2 in sentence: 'The European Union (EU) has also created an initiative called Horizon 2020 that aims to invest €1 billion per year into research projects related to future technologies, such as artificial intelligence, robotics, nanotechnology, and advanced manufacturing processes.
# '
#
# - 'Union' found in document 2 in sentence: 'The European Union (EU) has also created an initiative called Horizon 2020 that aims to invest €1 billion per year into research projects related to future technologies, such as artificial intelligence, robotics, nanotechnology, and advanced manufacturing processes.
# '
#
# - 'EU' found in document 2 in sentence: 'The European Union (EU) has also created an initiative called Horizon 2020 that aims to invest €1 billion per year into research projects related to future technologies, such as artificial intelligence, robotics, nanotechnology, and advanced manufacturing processes.
# '
#
# - 'Horizon' found in document 2 in sentence: 'The European Union (EU) has also created an initiative called Horizon 2020 that aims to invest €1 billion per year into research projects related to future technologies, such as artificial intelligence, robotics, nanotechnology, and advanced manufacturing processes.
# '
#
# - '2020' found in document 2 in sentence: 'The European Union (EU) has also created an initiative called Horizon 2020 that aims to invest €1 billion per year into research projects related to future technologies, such as artificial intelligence, robotics, nanotechnology, and advanced manufacturing processes.
# '
#
# - 'AI' found in document 2 in sentence: 'Regional Insights
#
# In 2021, North America dominated the AI market and accounted for a revenue share of more than 42%.'
#
# - 'AI' found in document 2 in sentence: 'As such, North America is expected to hold the largest share of the AI market during the coming years.'
#
# - 'Baidu' found in document 2 in sentence: 'For example, Baidu, Inc., a Chinese Internet behemoth, stated in April 2018 that it had entered into definitive agreements with investors about the sale of its financial services group, which provides wealth management, consumer lending, and other commercial services.'
#
# - ',' found in document 2 in sentence: 'For example, Baidu, Inc., a Chinese Internet behemoth, stated in April 2018 that it had entered into definitive agreements with investors about the sale of its financial services group, which provides wealth management, consumer lending, and other commercial services.'
#
# - 'Inc.' found in document 2 in sentence: 'For example, Baidu, Inc., a Chinese Internet behemoth, stated in April 2018 that it had entered into definitive agreements with investors about the sale of its financial services group, which provides wealth management, consumer lending, and other commercial services.'
#
# - 'AI' found in document 2 in sentence: 'This is due to increased revenue generated from the sale of AI products and'
#
#
# Matches for pattern [{'LIKE_NUM': True}, {'TEXT': '%'}]:
# - '20.1%' found in document 1 in sentence: 'The global AI market size is projected to grow from USD 387.45 billion in 2022 to USD 1394.30 billion in 2029 at a CAGR of 20.1% in the forecast period.'
#
# - '23%' found in document 1 in sentence: 'Share on LinkedIn (opens new window)
#
#     Share on Twitter (opens new window)
#
# Acquisition will combine solutions and expertise to deliver new cloud and AI capabilities across healthcare and other industries
#
# Microsoft and Nuance logos
#
# REDMOND, Wash., and BURLINGTON, Mass. – April 12, 2021 – Microsoft Corp (Nasdaq: MSFT) and Nuance Communications, Inc. (Nasdaq: NUAN) today announced they have entered into a definitive agreement under which Microsoft will acquire Nuance for $56.00 per share, implying a 23% premium to the closing price of Nuance on Friday, April 9, in an all-cash transaction valued at $19.7 billion, inclusive of Nuance’s net debt.'
#
# - '55%' found in document 1 in sentence: 'Nuance solutions are currently used by more than 55% of physicians and 75% of radiologists in the U.S., and used in 77% of U.S. hospitals.'
#
# - '75%' found in document 1 in sentence: 'Nuance solutions are currently used by more than 55% of physicians and 75% of radiologists in the U.S., and used in 77% of U.S. hospitals.'
#
# - '77%' found in document 1 in sentence: 'Nuance solutions are currently used by more than 55% of physicians and 75% of radiologists in the U.S., and used in 77% of U.S. hospitals.'
#
# - '37%' found in document 1 in sentence: 'Nuance’s Healthcare Cloud revenue experienced 37% year-over-year growth in Nuance’s fiscal year 2020 (ended September 2020).
#
# '
#
# - '38.1%' found in document 2 in sentence: 'And according to Grand View Research, Inc., it is projected to expand at a compound annual growth rate (CAGR) of 38.1% from 2022 to 2030.'
#
# - '66%' found in document 2 in sentence: 'The services portion accounted for around 66% share in 2016.'
#
# - '115%' found in document 2 in sentence: 'According to Tortoise Intelligence, global investment in AI firms has surged by 115% since 2020, the biggest year-over-year increase in AI investment in at least two decades.
#
# '
#
# - '42%' found in document 2 in sentence: 'Regional Insights
#
# In 2021, North America dominated the AI market and accounted for a revenue share of more than 42%.'
#
#
# Matches for pattern [{'LOWER': 'artificial'}, {'LOWER': 'intelligence'}]:
# - 'Artificial Intelligence' found in document 1 in sentence: 'Fortune Business Insights™ published this information in its recent report, titled “Artificial Intelligence Market Forecast, 2022-2029.”'
#
# - 'artificial intelligence' found in document 1 in sentence: 'The rising demand for artificial intelligence technology across various induce verticals such as a retail, BFSI, healthcare, food and beverages, automotive, and logistics is significantly contributing towards the growth of the global market.
#
# '
#
# - 'artificial intelligence' found in document 2 in sentence: 'The global artificial intelligence market size was $93.5 billion in 2021.'
#
# - 'Artificial intelligence' found in document 2 in sentence: 'Additionally, advancements in cloud computing technology, along with developments in deep learning algorithms, have increased the adoption rate of AI.
#
# Artificial intelligence growth can be attributed to its widespread application across diverse sectors, including healthcare, retail, and finance.'
#
# - 'artificial intelligence' found in document 2 in sentence: 'The artificial intelligence market is segmented based on product type, application, and region.'
#
# - 'Artificial Intelligence' found in document 2 in sentence: 'Artificial Intelligence Market by Component Analysis
#
# AI market analysis can be segmented into hardware, software, and service components.'
#
# - 'Artificial Intelligence' found in document 2 in sentence: 'Artificial Intelligence Market by Technology
#
# There are many different types of artificial intelligence, so it can be difficult to understand the market without an overview of the technology.'
#
# - 'artificial intelligence' found in document 2 in sentence: 'Artificial Intelligence Market by Technology
#
# There are many different types of artificial intelligence, so it can be difficult to understand the market without an overview of the technology.'
#
# - 'Artificial Intelligence' found in document 2 in sentence: 'Artificial Intelligence Market by End-User Industry
#
# The AI market is segmented by end-user industry into retail, healthcare and life sciences, automotive and transportation, BFSI, consumer goods and retail, manufacturing, media and entertainment, agriculture and food, and energy and utilities.
#
# '
#
# - 'artificial intelligence' found in document 2 in sentence: 'The automotive industry also accounted for a sizable share of the global artificial intelligence market.'
#
# - 'Artificial Intelligence' found in document 2 in sentence: 'Manufacturing and retail are expected to grow in hiring AI-related jobs, thus catching up with healthcare, finance, and other service industries that have been strong early adopters of AI.
# Growing Investments in Artificial Intelligence Systems
#
# '
#
# - 'artificial intelligence' found in document 2 in sentence: 'The European Union (EU) has also created an initiative called Horizon 2020 that aims to invest €1 billion per year into research projects related to future technologies, such as artificial intelligence, robotics, nanotechnology, and advanced manufacturing processes.
# '
#
# - 'artificial intelligence' found in document 2 in sentence: 'For instance, President Trump unveiled the American AI Initiative in February 2019 as the nation’s strategy for advancing leadership in artificial intelligence.'
#
# - 'artificial intelligence' found in document 2 in sentence: 'This expansion is attributable to the increased investments in artificial intelligence.'
#
#
# Matches for pattern [{'LOWER': 'ai'}, {'POS': 'VERB'}]:
# - 'AI grew' found in document 2 in sentence: 'According to an annual study on AI and its impact and progress developed by Stanford HAI, hiring, investment, and adoption of AI grew in 2020, reflecting long-term business trends that would likely outlive the pandemic’s effects.
#
# '

# %% [markdown]
# # Part B

# %%
# Detect encoding for each file
encoding_balzac = detect_encoding("documents/HonoreDeBalzac.txt")
encoding_alice = detect_encoding("documents/AliceBrown.txt")
encoding_chesterton = detect_encoding("documents/Chesterton.txt")

balzac_text = open("documents/HonoreDeBalzac.txt", encoding=encoding_balzac).read()
alice_text = open("documents/AliceBrown.txt", encoding=encoding_alice).read()
chesterton_text = open("documents/Chesterton.txt", encoding=encoding_chesterton).read()

# %%
# Create SpaCy documents
balzac_doc = nlp(balzac_text)
alice_doc = nlp(alice_text)
chesterton_doc = nlp(chesterton_text)

# %%
def print_word_count(*docs):
    for i, doc in enumerate(docs, start=1):
        word_count = len([token for token in doc if not token.is_space])
        print(f"Document {i}: Word Count - {word_count} words")

# Assuming nlp is the SpaCy model loaded earlier
print_word_count(balzac_doc, alice_doc, chesterton_doc)
# Out:
# Document 1: Word Count - 7127 words
# Document 2: Word Count - 5851 words
# Document 3: Word Count - 6416 words

# %%
def compare_similarity_of_first_100_tokens(*doc_name_pairs):
    for i, (doc_name1, doc1) in enumerate(doc_name_pairs):
        for _, (doc_name2, doc2) in enumerate(doc_name_pairs[i+1:]):
            # Extract the first 100 tokens from each document
            tokens1 = [token.text for token in doc1[:100]]
            tokens2 = [token.text for token in doc2[:100]]

            # Convert token lists to strings for similarity comparison
            text1 = " ".join(tokens1)
            text2 = " ".join(tokens2)

            # Calculate and print the similarity between the first 100 tokens
            similarity = nlp(text1).similarity(nlp(text2))
            print(f"Similarity between {doc_name1} and {doc_name2} (First 100 Tokens): {similarity:.4f}")

docs = [("HonoreDeBalzac", balzac_doc), ("AliceBrown", alice_doc), ("Chesterton", chesterton_doc)]
compare_similarity_of_first_100_tokens(*docs)
# Out:
# Similarity between HonoreDeBalzac and AliceBrown (First 100 Tokens): 0.8915
# Similarity between HonoreDeBalzac and Chesterton (First 100 Tokens): 0.8936
# Similarity between AliceBrown and Chesterton (First 100 Tokens): 0.9286

# %%
def add_custom_entity(text, entity_text, label, model):
    # Process the text with the existing model
    doc = model(text)

    # Find the start and end positions of the entity text
    start = None
    end = None
    for token in doc:
        if token.text == entity_text:
            start = token.idx
            end = token.idx + len(token.text)
            break

    if start is not None and end is not None:
        # Add a custom entity to the model
        doc.ents = list(doc.ents) + [(start, end, label)]

        # Process the text with the updated model
        doc = model(text)

    return doc

sample_text = "Hello, unfortunately Nikola Velikov is not available at this moment. Please leave a message after the tone."

entity_text = "Nikola Velikov"

# Add the custom entity to the model
custom_entity_doc = add_custom_entity(sample_text, entity_text, "PERSON", nlp)

print("Entities in the document:")
for ent in custom_entity_doc.ents:
    print(f"{ent.text}: {ent.label_}")
# Out:
# Entities in the document:
# Nikola Velikov: PERSON

# %% [markdown]
# # Part C

# %%
print("Pipeline components:", nlp.pipe_names)
# Out:
# Pipeline components: ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
@spacy.Language.component("print_longest_token")
def print_longest_token(doc):
    longest_token = max(doc, key=lambda token: len(token.text))
    print("Longest token:", longest_token.text)
    return doc

# Uncomment for the first time
nlp.add_pipe("print_longest_token", last=True)

print("Pipeline components:", nlp.pipe_names)

# Example text
text = "This is me being creative and smart using some long words like elephantiasis(i have no idea what it means, saw it on tiktok) and antidisestablishmentarianism."

# Process the text with the updated pipeline
doc = nlp(text)
# Out:
# Pipeline components: ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner', 'print_longest_token']
# Longest token: antidisestablishmentarianism
